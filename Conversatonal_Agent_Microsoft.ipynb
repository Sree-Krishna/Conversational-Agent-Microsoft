# %%
import json

# Opening JSON file
f = open('/content/MSDialog-Intent.json')

# returns JSON object as
# a dictionary
data = json.load(f)
indexes = list(data.keys())

# %% [markdown]
# # Query formulation and Preprocessing Dataset

# %%
titles = [data[indexes[i]]['title'] for i in range(len(indexes))]
titles_clean =[]
for title in titles:
  temp = ''
  for word in title.split():
    temp += word.lower() + ' '
  titles_clean.append(temp)

# %%
# I have written about 50 queries leveraging the use of title from above
queries = [
    "Why does 'backgroundtaskhost.exe' stop working?",
    "How to improve system performance and maintenance for Microsoft Edge on Windows 10?",
    "Troubleshooting start menu issues in Windows 10.",
    "Fixing screen sketch problems.",
    "Dealing with high CPU usage by 'remsh.exe' in the task manager.",
    "Steps to remove Skype for Business from Windows 10.",
    "Resolving the error 'Something went wrong' during Windows 10 factory reset.",
    "Fixing network setup issues on Windows.",
    "Understanding the difference between legacy and UEFI in Dell E6420 BIOS.",
    "Explaining the functionality of the charms menu in Windows.",
    "Best practices for backup in Windows 10 on an HP x360 laptop.",
    "How to fix sudden screen dimming while playing games on a laptop.",
    "Addressing graphics issues after an update in Microsoft Edge.",
    "Troubleshooting restart issues after an update on October 1.",
    "Resolving BSOD loop on new hardware.",
    "Understanding the '0x801901f4' error.",
    "Exploring features of the Creator's Update for a tablet.",
    "Fixing keyboard issues on Toshiba Satellite S50-C after Creators Update.",
    "Resolving 'Bad System Config File' stop code.",
    "Registering '.ocx' files in Windows.",
    "Fixing application error 0xc00000e5.",
    "Making ITNS-300 negative scanner work on Windows 10.",
    "Troubleshooting Xbox One controller issues after Windows 10 anniversary update.",
    "Transferring Windows 10 Pro license on hard drive failure.",
    "Handling the Cumulative Update error (KB4040724) in Windows 10.",
    "Improving super slow and unresponsive Windows 10.",
    "Fixing Event ID 2 Kernel-EventTracing error.",
    "Making Windows Explorer always open in details view.",
    "Resolving Microsoft .NET Framework error after laptop comes out of sleep.",
    "Avoiding crashes of third-party applications when changing directories in open file dialog.",
    "Fixing Windows 10 update stuck at 89%.",
    "Addressing issues with invisible settings in Windows 10.",
    "Best practices for backing up everything on a laptop.",
    "Restoring data from Quick Access in Windows 10.",
    "Handling USB reset failure in Windows 10.",
    "Fixing overlapping taskbar in Windows 10.",
    "Troubleshooting Windows 10 update issues.",
    "Seeking help with scans on a computer.",
    "Resolving force shutdowns during Windows update.",
    "Recovering lost contacts after upgrading to Windows 10.",
    "Troubleshooting Windows 10 Start Menu problems.",
    "Creating a backup CD in Windows 10.",
    "Addressing Windows Installer loop after upgrading to Office 2016.",
    "Disabling full row select in Windows 10.",
    "Unable to download from the Windows Store – how to fix?",
    "General queries about Windows 10.",
    "Understanding normal file structure in Windows 10.",
    "Dealing with Windows 10 hanging issues.",
    "Fixing encrypted USB drive issues after Windows 10 update.",
    "Resolving desktop stuck and never loading issues in Windows 10."
]

# %%
follow_up = {}
f_id = 0
potential_answer = {}
p_id = 0
for i in range(1000):
  values = data[indexes[i]]
  for utterance in values['utterances']:
    if utterance['affiliation'] != 'Common User' and ('CQ' in utterance['tags'] or 'FD' in utterance['tags'] or 'FQ' in utterance['tags']):

      follow_up[f_id] = ' '.join([word.lower() for word in utterance['utterance'].split()])
      f_id += 1
    if utterance['affiliation'] != 'Common User' and ('IR' in utterance['tags'] or 'PA' in utterance['tags'] ):
      potential_answer[f_id] = ' '.join([word.lower() for word in utterance['utterance'].split()])
      p_id += 1

# %%
print('Total follow up questions:', f_id+1)
print('Total answers:', p_id+1)
# Out:
# Total follow up questions: 562
# Total answers: 1665

# %% [markdown]
# # Baseline Binary Relevance

# %%
from gensim.parsing.preprocessing import preprocess_string

# Preprocess documents
preprocessed_documents = [preprocess_string(doc) for doc in follow_up.values()]
print(preprocessed_documents[10])
# Define functions for AND and OR operations
def AND(query1, query2):
    results1 = [i for i, doc in enumerate(preprocessed_documents) if set(query1).issubset(set(doc))]
    results2 = [i for i, doc in enumerate(preprocessed_documents) if set(query2).issubset(set(doc))]
    return list(set(results1) & set(results2))

def OR(query1, query2):
    results1 = [i for i, doc in enumerate(preprocessed_documents) if set(query1).issubset(set(doc))]
    results2 = [i for i, doc in enumerate(preprocessed_documents) if set(query2).issubset(set(doc))]
    return list(set(results1) | set(results2))

# Example usage
query1 = preprocess_string('Windows 10 Microsoft Edge is slow - System Performance and maintenance')[:2]
query2 = preprocess_string('Windows 10 factory reset error "Something Went Wrong" after selecting Language, Keyboard and Language.')[:2]
print(query1, query2)
and_results = AND(query1, query2)
or_results = OR(query1, query2)

print(f"Documents matching both queries: {and_results}")
print(f"Documents matching at least one query: {or_results}")
# Out:
# ['hello', 'window', 'new', 'laptop', 'ultra', 'confus', 'understand', 'wai', 'dai', 'window', 'backup', 'window', 'imag', 'creat', 'backup', 'medium', 'futur', 'recoveri', 'need', 'told', 'gather', 'confus', 'blog', 'window', 'file', 'histori', 'backup', 'maintain', 'version', 'file', 'window', 'imag', 'cover', 'window', 'file', 'histori', 'backup', 'suggest', 'got', 'us', 'macrium', 'reflect', 'free', 'version', 'window', 'imag', 'recoveri', 'purpos', 'separ', 'us', 'window', 'file', 'histori', 'backup', 'privat', 'creat', 'file', 'folder', 'sound', 'interest', 'impli', 'think', 'keep', 'distinct', 'separ', 'backup', 'window', 'imag', 'import', 'file', 'advic', 'tip', 'suggest', 'proper', 'approach', 'highli', 'appreci', 'thank', 'advanc']
# ['window', 'microsoft'] ['window', 'factori']
# Documents matching both queries: [648]
# Documents matching at least one query: [512, 260, 516, 648, 1034, 524, 655, 400, 532, 22, 155, 28, 32, 33, 34, 417, 1057, 294, 696, 313, 58, 189, 829, 454, 329, 844, 205, 589, 591, 336, 86, 607, 736, 1005, 366, 882]

# %%
follow_up[648]
# Out:
# '  I beg you Microsoft in the Mighty name of God  please send or activate my Lenovo Yoga 11 Window RT8.1. I have done factory reset severally and still NO PRODUCT KEY, NO PRODUCT ID. If I try to do Window Update it will reply me unable to get window update, if I try to access Microsoft office I will get MICROSOFT CAN"T READ THE LICENSE OF THE COMPUTER AND CAN"T REPAIR IT. I tried to do window Activate Window by PHONE which display STEP1 Call one of the Numbers to get confirmation ID STEP 2: Provide this number when you are asked; 1 2 3 4 5 6 7 8 9 STEP3: Enter the Confirmation ID you get Over the Phone; A B C D E F G H with a box under each alphabets  The most suprising thing is they connected me to even their technical department and they still can\'t solve me problems. No what do I do? will I just throw away this computer or what do you advise PLEASE HELP '

# %% [markdown]
# Very less query matches are returned as its just a basic comparison and it requires that all the query words be present in the document, which is not most of the case, unless the query is very small of the size 2 or 3 words

# %%
bm25_a = {}
bm25_f = {}
ql_a = {}
ql_f = {}
tf_a = {}
tf_f = {}

# %% [markdown]
# # BM25

# %%
import math
from collections import Counter

class BM25:
    def __init__(self, corpus, k1=1.5, b=0.75):
        self.corpus = corpus
        self.k1 = k1
        self.b = b
        self.doc_lengths = [len(doc) for doc in corpus]
        self.avg_doc_length = sum(self.doc_lengths) / len(self.doc_lengths)
        self.doc_count = len(corpus)
        self.doc_freqs = [Counter(doc) for doc in corpus]

    def idf(self, term):
        doc_count_with_term = sum(1 for doc in self.corpus if term in doc)
        return math.log((self.doc_count - doc_count_with_term + 0.5) / (doc_count_with_term + 0.5) + 1.0)

    def bm25_score(self, query, doc, doc_index):
        score = 0
        for term in query:
            tf = doc.count(term)
            idf = self.idf(term)
            doc_length = self.doc_lengths[doc_index]
            numerator = tf * (self.k1 + 1)
            denominator = tf + self.k1 * (1 - self.b + self.b * (doc_length / self.avg_doc_length))
            score += idf * numerator / denominator
        return score

    def rank_documents(self, query):
        scores = [(doc_index, self.bm25_score(query, self.corpus[doc_index], doc_index)) for doc_index in range(self.doc_count)]
        ranked_docs = sorted(scores, key=lambda x: x[1], reverse=True)
        return ranked_docs


corpus = list(potential_answer.values())
bm25_model = BM25(corpus)
bm25_follow_up = BM25(titles_clean)
i = 1
for query in queries:
  print('Query ', i, ':', query)
  query = [word.lower() for word in query.split()]
  ranked_documents = bm25_model.rank_documents(query)
  bm25_a[i] = [i for i, s in ranked_documents[:5]]
  for index, score in ranked_documents[:5]:
      print(f"Document {index + 1}: BM25 Score - {score}")
      print(corpus[index])
  print('\nFollow Up\n')
  follow_up_documents = bm25_follow_up.rank_documents(query)
  bm25_f[i] = [i for i, s in follow_up_documents[:5]]
  for index, score in follow_up_documents[:5]:
    print(f"Document {index + 1}: BM25 Score - {score}")
    print(titles_clean[index])
  print('\n\n')
  i+=1

# Below are the 50 queries with top 5 relevant documents displayed using BM25 Model
# Followed by this is the set of 5 potential follow up queries the user can select as the next question in a conversation
# Out:
# Query  1 : Why does 'backgroundtaskhost.exe' stop working?
# Document 430: BM25 Score - 7.590244908013002
# hi paul, welcome to the skype community forum. i know how important it is for you to use the 4.17.135 skype version. however, we have fully stopped supporting this version and upgraded the app to 4.18.15 and that's the reason why you're getting the same error message all over again. we always recommend to use the latest version of skype for the best possible experience. there are few reasons why you should update your application(s): i hope this helps. kindly let us know if you have questions. regards, rhiza_emonica
# Document 25: BM25 Score - 6.413318909496925
# hi denise, there are several possible reasons why you are unable to send an email in outlook.com. it can be because the message or attachments are too large or your inbox is full. for information and steps on how to resolve the issue with sending emails in outlook.com, you can refer to the article on this link. to stop or cancel an email that you are sending, you can check the steps provided in hansv mvp's post by clicking this link. if you have other questions, don't hesitate to reach out. regards.
# Document 471: BM25 Score - 5.068488882844309
# it is not an ordinary pc, which is why windows 10 cannot be installed in it. it has got the same kind of processor as a mobile phone, which is why it has a special version of windows (rt) to run on it. normal windows is incompatible.
# Document 285: BM25 Score - 4.551440126815978
# i have discovered an answer. it is microsoft and bing with the issue. i experimented with substituting the "user agent" in the browsers. i tested several variations: also tested the following: so, the actual browser used doesn't make a difference, just what browser it claims to be when communicating with bing. it looks like microsoft and bing are "browser sniffing" opera and either purposefully or accidentally sending a different bing search webpage. why am i not surprised? for now i'm using the same user agent switching add-ons i used for testing so i can function with bing search. it is a work-around that i shouldn't have to use.
# Document 81: BM25 Score - 4.496309470028671
# why should the numbers be 943? if i manually add the numbers in column f as shown on your second image, i get 945.01.
#
# Follow Up
#
# Document 2080: BM25 Score - 12.012470974577553
# why is the set goal link not working?
# Document 2097: BM25 Score - 8.258957300258809
# why doesn't my bing swagcode work?
# Document 2124: BM25 Score - 7.86364100991829
# why did bing stop the name scheme (bing image id)?
# Document 1895: BM25 Score - 7.053106548718111
# [resolved] bing doesn' stop asking me for keeping cookies.
# Document 2064: BM25 Score - 6.700548644885344
# does anyone know why my bing whether app will not open?
#
#
#
# Query  2 : How to improve system performance and maintenance for Microsoft Edge on Windows 10?
# Document 257: BM25 Score - 13.492212766978366
# hi, when edge was introduced for the first time, i was one of the hopefuls that one day microsoft edge would somehow be released for windows 7 or windows 8 and 8.1 as well. unfortunately, since the edge browser is a built-in application on the new universal windows platform, it wouldn't be possible to install edge on windows 7. we suggest though that you relay this great idea to our developers via our feedback hub so they can look into this, and possibly consider the idea in the future. feel free to contact us if you need further assistance with windows.
# Document 440: BM25 Score - 12.708236135177053
# hi, resetting microsoft edge through powershell to correct the misbehavior of the program. before you reset microsoft edge through powershell, we strongly recommend that you perform a full backup and/or create a system restore point first. the steps in resetting microsoft edge through powershell are as follows. step 1 navigate on the following folder (replace %username with your own username.) and clear everything inside it: c:users\%usernameappdatalocalpackagesmicrosoft.microsoftedge_8wekyb3d8bbwe step 2 right-click on the start menu and choose “windows powershell (admin)”. copy and paste the following code inside powershell and press enter: get-appxpackage -allusers -name microsoft.microsoftedge | foreach {add-appxpackage -disabledevelopmentmode -register “$($_.installlocation)appxmanifest.xml” -verbose} when you open microsoft edge next time, you will see that it has been reset to default. if you encounter any error, type the following command to get the first few logged events: get-appxlog | out-gridview note the error code in the log and proceed here. check if the issue persists. regards.
# Document 15: BM25 Score - 12.532436680242762
# hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 95: BM25 Score - 12.366445646252668
# try resetting microsoft edge: open start, type: powershell right click powershell then click run as administrator at the prompt, type: get-appxpackage -allusers -name microsoft.microsoftedge | foreach {add-appxpackage -disabledevelopmentmode -register “$($_.installlocation)appxmanifest.xml” -verbose} hit enter when complete, exit powershell, restart your computer then check if edge is working again. if that does not work, try uninstalling the recent update to see if you can browse using edge again: press windows key + r type: appwiz.cpl hit enter click view installed updates select the recent update right click it then click uninstall. also, try opening the browser through the run command and check if it launches: 1. press windows key + r. 2. type microsoft-edge:// and press enter. if it shows up on the taskbar, right click it then click pin to taskbar.
# Document 14: BM25 Score - 11.958624150286676
# hi, the slow or unresponsive performance of windows 10 may be due to a third-party program or other factors like outdated drivers and system issues. for us to better assist you, we would like to ask for additional information. please answer the following: we hope to hear from you soon.
#
# Follow Up
#
# Document 2: BM25 Score - 26.75618553784618
# windows 10 microsoft edge is slow - system performance and maintenance
# Document 499: BM25 Score - 13.840686413441878
# microsoft edge on windows 7 and 8.1?
# Document 6: BM25 Score - 11.6454094253324
# how can i remove skype for business from windows 10?
# Document 1793: BM25 Score - 11.553582846009082
# why do i have to sign into bing everytime i open edge in windows 10?
# Document 1836: BM25 Score - 10.80940267486546
# no bing bar for microsoft edge?
#
#
#
# Query  3 : Troubleshooting start menu issues in Windows 10.
# Document 2: BM25 Score - 8.781753735087657
# we appreciate your response. your concern about connectivity issues can be due to software conflicts related to the specified program that you're using. the specified application installs usb drivers and lists a number of items to consider when using usb as your preferred private branch exchange (pbx) setting. this may have brought changes to the configuration of the usb ports that led to conflicts on your device. we'd recommend performing a clean boot in windows to isolate software conflicts on your device. to do this, you can perform the steps posted on this link. in the clean boot environment, check if you'll still experience connectivity issues when using the application along with the 3g dongle. the link will also provide steps to isolate the possible cause of the issue. once you're done troubleshooting, check the how to reset the computer to start normally after clean boot troubleshooting section to revert your device to normal boot. in the event that you'll still experience your concern, we'd recommend performing the following to assist in identifying application specific issues: we look forward to an update on your concern.
# Document 447: BM25 Score - 8.770088252723156
# i suggest starting off with easy troubleshooting steps. first, please restart your mac. did the problem go away?
# Document 353: BM25 Score - 8.322364030795395
# you are welcome. @@@@@@@@@@@@@@@@@@ if you do want to try 10 again on that machine follow these steps to clean install 10: find the windows 10 media creation tool on the software download page "start fresh with a clean installation of windows 10" https://www.microsoft.com/en-us/software-download/windows10startfresh "how to clean install windows 10" http://www.tenforums.com/tutorials/1950-windows-10-clean-install.html ________________________________________________ when your free upgrade to 10 was originally activated microsoft will have kept the hardware configuration details of your device on their servers for recognition purposes if you have to reinstall 10. "activation in windows 10" (digital entitlement) https://support.microsoft.com/en-au/help/12440/windows-10-activation cheers.
# Document 485: BM25 Score - 8.264153428634653
# there are some known issues between older version of mac os (such as sierra 10.12.x) and ms office. can you please try to upgrade your os to high sierra? https://support.apple.com/macos/high-sierra please let usknow if this helps. ciao and thanks james
# Document 12: BM25 Score - 8.23663943421732
# hi, windows 10 creators update requires a hard disk space of at least 16 gb for a 32-bit operating system or 20 gb for a 64-bit operating system. if your storage space is not enough to install windows 10 creators update, you can try freeing some drive space. here’s a link that would walk you through the steps on how to free up drive space in windows 10. we launch updates to add new features and ensure that your system is working efficiently. you can schedule update using active hours in windows 10. however, we have yet to include the option to decline or stop the update. we recommend that you post your suggestion to our feedback hub by following the steps below: 1. type “feedback hub” in cortana search and launch the app. 2. navigate to feedback in the left menu and press + add new feedback. 3. select the problem, and share any details you think are relevant, and choose an appropriate category and subcategory. 4. important: if possible, reproduce the problem(s) after clicking begin monitoring (or start capture) near the end of the form; stop monitoring when you’re done. 5. once you’ve completed the form and monitoring, click submit. 6. click continue using feedback hub. 7. click my feedback at the top, and then find the item you submitted (it may take a while to appear). 8. open the item you submitted and click share. 9. click copy link, then paste the link here in your response (it will look like https://aka.ms/<unique link>) you can visit this link for the instruction on how to set active hours in windows 10. let us know if you need additional assistance.
#
# Follow Up
#
# Document 43: BM25 Score - 14.826633275693679
# windows 10 start menu
# Document 3: BM25 Score - 13.22578783087284
# start menu
# Document 56: BM25 Score - 8.097938521894529
# adobe flash update with windows 10.
# Document 193: BM25 Score - 8.018783342390222
# skype on windows won't start
# Document 61: BM25 Score - 7.4108614307218765
# windows start up time setting display
#
#
#
# Query  4 : Fixing screen sketch problems.
# Document 1: BM25 Score - 6.50018200516455
# hi, windows is open to new ideas. your feedback is highly appreciated and will help us to improve our ability to serve you and other users of screen sketch. you can always submit your suggestions using the windows feedback hub. when you submit a feedback item, we gather additional details and information about your issue that will help our engineers address it. feedback items regularly receive microsoft responses on the submissions in the feedback app so you can see what we are doing about your feedback. you can either submit a new feedback or upvote an existing feedback item by following the steps provided on this link. feel free to get back to us if we can help you with anything else.
# Document 58: BM25 Score - 3.7407795141705713
# hello, would you mind posting a screenshot of the window? upload it in your next reply using the insert image icon in the menu above. it is next to the last icon on the right. which browser are you using? which windows version? i'm unable to reproduce the issue. how to take a screenshot.
# Document 268: BM25 Score - 3.7296635666147515
# the tool is showing in your 2nd screenshot so i'm not sure i understand?
# Document 186: BM25 Score - 3.625802901678759
# hi, let me ask you; i would suggest you to provide more details regarding the issue you’re facing. please see the article provided below, which will guide you on how to ask questions. suggestions for asking a question on help forums also, i would request you to post us back with a screen shot of the issue, so that we can help you better. you can refer to the following article to include a screenshot to your post. how to include a screenshot in your post please revert to this response along with answers to questions asked, we will be glad to help you further.
# Document 160: BM25 Score - 3.5972952897137542
# hi kristen, thanks for sharing your experience with us. regarding this issue, please change the file extension name from ppt into pptx to check whether you can open the file. meanwhile, please share more details with us if the issue persist: 1) right click the file on your mac and choose get info to capture a screenshot about the properties of this file. 2) how did you save your changes after you first open it? 3) capture a screenshot about the error message. 4) go to powerpoint > about powerpoint to capture a screenshot about the product information. regards, williamdiane
#
# Follow Up
#
# Document 4: BM25 Score - 14.9429908493512
# screen sketch issue
# Document 388: BM25 Score - 5.742151402832582
# share screen
# Document 60: BM25 Score - 5.578770995450951
# screen flicker
# Document 583: BM25 Score - 5.3504192133200785
# share screen view
# Document 644: BM25 Score - 5.3504192133200785
# screen minimizing
#
#
#
# Query  5 : Dealing with high CPU usage by 'remsh.exe' in the task manager.
# Document 491: BM25 Score - 28.274092734445055
# i'd start with task manager. press control + alt + delete and click task manager. the various tabs in taskman will show you which programs/processes/services are eating the most memory and cpu time. i'd first check the performance tab and click memory to make sure that nothing's eating all or most all of available memory, then go to the processes tab and click cpu to sort the list from highest to lowest percentage. look for processes that are eating lots of cpu time.
# Document 244: BM25 Score - 8.618241493991526
# hello daniel, the problem that you are experiencing with the bottom taskbar in powerpoint 2016 is possibly caused by a 3rd party add-ins. to better assist you, we suggest that you try to disable all 3rd party add-ins or run powerpoint in safe mode and verify the result. you can also repair the powerpoint app by going to this link. let us know how it goes.
# Document 143: BM25 Score - 8.179235007938248
# right-click on a blank area of the taskbar and select properties/ taskbar/ taskbar buttons, and set it for "never combine", see if they still disappear?
# Document 314: BM25 Score - 6.790435802873979
# hi michael, welcome to the skype community forum. i do understand the inconvenience you have faced. let me help you on this. there’s probably an issue with the internet connection (yours or the person you’re calling), or with your device. let's resolve this by following the steps below: important: if you’d like to keep your chat and call history, skip this step. *by default, the library folder is hidden in mac os x v10.7 “lion” and higher. to find your library folder, open finder and, from the menu bar, select go, press and hold the option key, and then select library. please let us know if you have other questions. regards, rhiza_eryan
# Document 76: BM25 Score - 6.583384626879695
# to a great extent it's a subjective decision. the article brandon referred you to provides some additional insight on the use of duplicate. i personally prefer to use duplicate depending on the task when working on a specific slide. also, you can duplicate a selection by holding option or control while dragging it. otoh, some of the limitations of duplicate are that:
#
# Follow Up
#
# Document 5: BM25 Score - 18.557306982639602
# remsh.exe started to appear in my task manager and to have high cpu usage
# Document 1537: BM25 Score - 18.472706128503667
# high cpu usage when using a different account
# Document 727: BM25 Score - 13.195524627251434
# high cpu load when using powerpoint
# Document 520: BM25 Score - 9.86628798264393
# image name ( the name of the process) is missing in task manager. no option to select "image name" column again?
# Document 1439: BM25 Score - 9.42274223428646
# is there a cpu meter app for windows 10 similar to the cpu meter gadget for windows 7?
#
#
#
# Query  6 : Steps to remove Skype for Business from Windows 10.
# Document 242: BM25 Score - 10.52273326324497
# hello christina r. pain management, welcome to skype community forum. in my experience, skype is best when using a windows desktop or laptop (i’m not sure for other skype users). you can do free skype-to-skype calls and video calls. you can also start group video calling with your family, friends and colleagues. and it is also free! instant messaging is also possible and free of charge. group chat is also available. you can do screen sharing with your colleagues and this is also free. you can also call mobile number, you need to have a skype credit or a calling subscription with this. there are also paid services that skype offers, however skype is designed for personal use only. you may want to check skype for business for you to use it for your business. let me know if this information helps. please do not hesitate to reply to this thread if you need further help.
# Document 82: BM25 Score - 9.656150215767806
# hi hana, since removing email addresses from windows live login bar, you may post your query in windows live support for further assistance. windows live support http://windowslivehelp.com/searchresults.aspx?query=remove%20email%20addresses%20from%20my%20window%20live%20login%20&productid=10
# Document 205: BM25 Score - 9.382896138916516
# hi, in order for you to remove these search results from the web, you need to manually remove your name from these images from the websites concerned. regards.
# Document 497: BM25 Score - 8.429505427764907
# wshelper.exe is wondershare. generally speaking you do not need it http://superuser.com/questions/800294/how-do-i-completely-remove-wondershare-allmytube-from-windows-using-farbar-reco
# Document 53: BM25 Score - 8.112696798560881
# hi petercoltheart, good day and welcome to skype community! discover contacts is an added feature of the new skype application. the purpose of this is for you to be able to easily add contacts on skype. take note that this feature cannot be removed from the app. i hope this answers your query. regards,
#
# Follow Up
#
# Document 6: BM25 Score - 16.999509162183113
# how can i remove skype for business from windows 10?
# Document 581: BM25 Score - 11.064566379526045
# can i use skype for business if im not a business customer?
# Document 877: BM25 Score - 10.231298247400108
# is mac 10.7.5 really too old for skype?
# Document 300: BM25 Score - 10.124930900463012
# skype for macbook air /10.7.5
# Document 1776: BM25 Score - 9.158753666728565
# remove bing desktop from taskbar
#
#
#
# Query  7 : Resolving the error 'Something went wrong' during Windows 10 factory reset.
# Document 275: BM25 Score - 10.394561518268095
# according to the article at http://support.microsoft.com/kb/883821, which is about errors during attempts to use windows update, "the 0x80072ee7 error code may occur if the client computer cannot find the correct ip address when it tries to resolve a url for the windows update web site or for the microsoft update web site. this error may occur if the hosts file contains a static ip address." the same error number might occur when the office installer tries to reach the activation server, if there is a problem with that address (not the windows update site). it's worth checking the reason given in the article (a static ip address in the hosts file). there are instructions in the resolution section, under the 0x80072ee7 error code heading, for how to find and read the file. except in very unusual circumstances, every line in the file can be commented out by putting a # character at the left margin. a static ip address isn't the only possibility. it's also possible that during the installation/activation you don't have a working internet connection, or that you don't have access to a domain name service (dns) server, or (unlikely) that the dns has a bad address for microsoft.
# Document 15: BM25 Score - 10.081217271235014
# hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 427: BM25 Score - 9.807129942888075
# hi , this is sarah from the microsoft community. lets see if we can get your problem resolved. since the computer already comes with a valid license for windows 7, i would just perform a factory reset and set it up with a new user account. new computers that come preinstalled with windows often have what is called a recovery partition. this is used to reinstall the operating system in the event of a system crash. to access it, you will need to boot into when you start your computer by pressing a function key. this can be either f1, f2, f9, f10, f11, f12 or even del or tab key. consult the owners manual that came with your pc for instructions about how to reinstall windows. this is how the recovery partition is accessed for the most popular makes.. for dell, press ctrl + f11 directly after powering up the unit for hp, press f11 directly after powering up the unit for lg, press f11 directly after powering up the unit for toshiba, press and hold '0' before and during the power up for acer, press and hold alt + f10 as soon as you see the logo for asus, press f9 as soon as you see the asus logo. for samsung, press f4 at power up.. for fujitsu, press the f8 key repeatedly directly after powering up for advent, restart your computer. then press f10 repeatedly until the message "starting system recovery" is displayed for sony vaio, restart and press "f8" or "f10" repeatedly until the "advanced boot options" screen appears. if you want to run something newer than windows 7, you might still be able to get windows 10 for free: https://www.groovypost.com/howto/download-windows-10-free/ best, andresarah windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
# Document 492: BM25 Score - 8.484102293127023
# since i saw explorer acting funny, i went to an explorer repair routine, rebooted and did an online repair of office (which is really a reinstallation). after that, all seems to be ok. by explorer acting funny i mean this. all my desktop icons flashed once, then had a little check sign attached to them, which went away after a second. and that happened occasionally when i moved windows around etc. the repair program said something about a corrupted recycle bin. interesting, the kind of consequences that can arise from seemingly innocent causes. butterfly effect!
# Document 3: BM25 Score - 7.629184420709669
# you'll need to reinstall to uefi, booting the installation media as a uefi device to delete all partitions down to unallocated space to clear the formatting - as illustrated in the gold standard clean install here: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 this is worth it because then you'll have the full modern features of the bios-replacing uefi which offers better security, gui with mouse support, and other improvements. http://www.youtube.com/watch?v=drmivy7bil4 a legacy install should eventually be replaced with uefi. before reinstall enable uefi in bios, if necessary csm or legacy mode while you have an mbr drive still needing to boot, secure boot.. you may need to turn off fast boot if it won't pause long enough to boot the installation media when you power up pressing the dell f12 key. but after install turn fast boot on unless you need to boot media as you'll access bios via recovery settings .
#
# Follow Up
#
# Document 7: BM25 Score - 13.885091088620936
# windows 10 factory reset error "something went wrong" after selecting language, keyboard and language.
# Document 2112: BM25 Score - 9.115277851359897
# my went away
# Document 1199: BM25 Score - 8.147651083751963
# windows 7 backup to external hd fails with 0x80070002 error. the external hd is disconnected during the backup process.
# Document 1790: BM25 Score - 8.098941570346257
# how can i remve the bing bar fix applied during windows update?
# Document 48: BM25 Score - 7.614520474837717
# windows 10
#
#
#
# Query  8 : Fixing network setup issues on Windows.
# Document 343: BM25 Score - 9.53796285400056
# hi, check with acer support as their could known issues. acer - usa - service and support - drivers http://us.acer.com/acer/service.do?languageisoctxparam=en&ctx2.c2att1=25&countryisoctxparam=us&ctx1g.c2att92=447&ctx1.att21k=1&crc=3618978704 acer - worldwide http://www.acer.com/worldwide/selection.html the acer site shows a bluetooth driver for vista but not windows 7 so it must use the default windows 7 drivers or is not supported - check with acer support. for the driver info go here and check extenze then select 4620 - be sure in middle of page to select the windows version you want to know about. http://us.acer.com/acer/service.do?languageisoctxparam=en&miu10einu24.current.attn2b2f2eef=3750&sp=page15e&ctx2.c2att1=25&miu10ekcond13.attn2b2f2eef=3750&countryisoctxparam=us&ctx1g.c2att92=453&ctx1.att21k=1&crc=2054404012 ===================================== troubleshooting : hardware devices not detected or not working - a mr fixit http://support.microsoft.com/gp/hardware_device_problems add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer set up a bluetooth enabled device http://windows.microsoft.com/en-us/windows-vista/set-up-a-bluetooth-enabled-device troubleshoot problems with bluetooth enabled devices http://windows.microsoft.com/en-us/windows-vista/troubleshoot-problems-with-bluetooth-enabled-devices how to setup a bluetooth connection http://www.wintuts.com/how-to-setup-a-bluetooth-connection the bluetooth item in control panel on a windows vista sp2-based computer does not work as expected when you click the item - for windows 7 check this manually http://support.microsoft.com/kb/960531/en-us if you need drivers try your system maker's support site and/or the actual device maker's site. bluetoothview is a small utility that runs in the background, and monitor the activity of bluetooth devices around you. for each detected bluetooth device, it displays the following information: device name, bluetooth address, major device type, minor device type, first detection time, last detection time, and more. bluetoothview can also notify you when a new bluetooth device is detected, by displaying a balloon in your taskbar or by playing a small beep sound. - free http://www.nirsoft.net/utils/bluetooth_viewer.html bluetoothcl is a small console application that dumps all current detected bluetooth devices into the standard output. for each bluetooth device, the following information is displayed: mac address, name, major device type, minor device type, and optionally the company name of the device (if external file of mac addresses - oui.txt is provided) - free http://www.nirsoft.net/utils/bluetoothcl.html bluetoothlogview is a small utility that monitors the activity of bluetooth devices around you, and displays a log of bluetooth devices on the main window. every time that a new bluetooth device arrives to your area and when the device leaves your area, a new log line is added with the following information: device name, device address, event time, event type ('device arrival' or 'device left'), device type, and the company that created the device. bluetoothlogview also allows you to specify a description for every device (according to its mac address) that will appear under the 'description' column. - free http://www.nirsoft.net/utils/bluetooth_log_view.html --------------------------------------------------------------------- change settings for a bluetooth enabled device http://windows.microsoft.com/en-us/windows7/change-settings-for-a-bluetooth-enabled-device add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer add a bluetooth or other wireless or network device: frequently asked questions http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-or-other-wireless-or-network-device-frequently-asked-questions ---------------------------------------------- ...
# Document 213: BM25 Score - 6.57545547439847
# 1) have you made any software or hardware changes to your computer recently? 2) is this a network printer? 3) what is the make and model of the printer? to work with this issue, refer these methods: method 1: make sure the below setting is correct for your printer. refer the step below. a) click start b) go to control panel c) choose printers d) right click on your printer and make sure that there is no check mark on the “use printer offline” option. this should put your printer back online. method 2: refer the link to open the printer troubleshooter http://windows.microsoft.com/en-us/windows7/open-the-printer-troubleshooter method 3: run the fixit from the following link to change the status of the printer. http://support.microsoft.com/kb/2027593 also refer, why can't i print? http://windows.microsoft.com/en-us/windows7/why-cant-i-print hope this information is helpful.
# Document 507: BM25 Score - 5.403405670790123
# the only supported version of skype on a chromebook is skype for web. if they have their chromebook modified in a fashion to run a version of skype for linux or android they should be running the latest builds (linux 5.x/preview or android 7.x/8x). if that is not working properly in their setup, they should revert to using skyep for web to contact you.
# Document 181: BM25 Score - 5.0038043181560745
# since you mentioned that you are a computer programmer, we suggest that you post your query to our microsoft developers network (msdn) forum page, where the community members are more versed with the matter. there are programmers and developers who can provide the best solution for your concern. if there's anything else, feel free to let us know.
# Document 68: BM25 Score - 4.697419893598745
# hello margaret, thank you for posting you query on microsoft community forums. as per description, you are unable to install the apps getting error message "something happened and your purchase can't be completed. error code: 0x800704d5 ". i would appreciate, if you can provide us the following information to help us understand the issue better? i would suggest you to follow the methods given below and check. method 1: make sure that the date and time are correct on the computer. a) check the setting for date/time by choosing the desktop tile and then left click on the date/time in the corner. b) click on change date and time settings. and then verify the time zone is correct as well as the internet time tab has the option to synchronize with internet time server. if issue still persists try method 2. method 2: clear the store cache you may try to clear the cache for the store and check if it helps: a) press the “windows logo” + “r” keys on the keyboard. b) type “wsreset.exe” and press “enter”. c) reboot the computer and then check the issues with the apps. if issue didn't get resolve try method 3. method 3: disable security software temporarily disable security software temporarily and check if the issue persists. disclaimer: antivirus software can help protect your computer against viruses and other security threats. in most cases, you should not disable your antivirus software. if you do have to temporarily disable it to install other software, you should re-enable it as soon as you're done. if you are connected to the internet or a network during the time your antivirus software is disabled, your computer is vulnerable to attacks. hope this information is helpful. please do let us know if you need further assistance with windows.
#
# Follow Up
#
# Document 8: BM25 Score - 15.873499744890514
# network setup issue
# Document 498: BM25 Score - 7.569967827593063
# login issues iphone
# Document 688: BM25 Score - 7.2464372721012955
# mic issues
# Document 1560: BM25 Score - 6.684289654886645
# network to xbox services on windows 8.1
# Document 1080: BM25 Score - 6.645004965090287
# space bar issues
#
#
#
# Query  9 : Understanding the difference between legacy and UEFI in Dell E6420 BIOS.
# Document 3: BM25 Score - 17.707106203140007
# you'll need to reinstall to uefi, booting the installation media as a uefi device to delete all partitions down to unallocated space to clear the formatting - as illustrated in the gold standard clean install here: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 this is worth it because then you'll have the full modern features of the bios-replacing uefi which offers better security, gui with mouse support, and other improvements. http://www.youtube.com/watch?v=drmivy7bil4 a legacy install should eventually be replaced with uefi. before reinstall enable uefi in bios, if necessary csm or legacy mode while you have an mbr drive still needing to boot, secure boot.. you may need to turn off fast boot if it won't pause long enough to boot the installation media when you power up pressing the dell f12 key. but after install turn fast boot on unless you need to boot media as you'll access bios via recovery settings .
# Document 320: BM25 Score - 6.817678684226916
# hello michelle, welcome to skype community forum. can you try to reset your wi-fi and then please try to uninstall/reinstall the skype application, then try to check if there are any difference to online status of your skype contacts. we look forward to your reply. regards,
# Document 485: BM25 Score - 6.7027792178675005
# there are some known issues between older version of mac os (such as sierra 10.12.x) and ms office. can you please try to upgrade your os to high sierra? https://support.apple.com/macos/high-sierra please let usknow if this helps. ciao and thanks james
# Document 374: BM25 Score - 6.251876319746758
# hello johncorks, welcome to skype community! my apology for the confusion. sending an sms message using the new skype for android is currently not available. for updates on when this feature will be available in the new skype for android, you can check this link from time to time. thank you for understanding. let us know if you need further assistance.
# Document 214: BM25 Score - 6.113805523097786
# hi revant, sorry for the delayed response. for better understanding of the issue, please provide us following information: i suggest you to check the date and time of your tablet and set it to the correct value, as with the incorrect date and time your tablet might not be able to access the updates. hope this helps, get back to us with the required information and we will be glad to assist you.
#
# Follow Up
#
# Document 9: BM25 Score - 31.30885200874409
# legacy v uefi - dell e6420 bios
# Document 594: BM25 Score - 12.29805764150294
# power options- difference between turn off the display and put the computer to sleep?
# Document 437: BM25 Score - 10.12259428139959
# dell 5110 random freezes
# Document 618: BM25 Score - 9.975577542273756
# between to dates is h2 between a2 and b2
# Document 1238: BM25 Score - 9.902322390342492
# what is the difference between answering a skype call as a phone call vs as a video call?
#
#
#
# Query  10 : Explaining the functionality of the charms menu in Windows.
# Document 70: BM25 Score - 6.802302863250038
# it seems like the issue was with the third-party browser that you are using. you may also try to reset the settings of the third-party browser and check if the issue persists. for further assistance, kindly contact the software developer of your third-party browser so that they can check if there are possible incompatibility issues with certain websites and their functionality. let us know if you have any other concerns.
# Document 232: BM25 Score - 6.412875118080459
# i'm not quite following your question. the syntax for the if() function is: if(condition, true result, false result) so if the condition is true the true result is display otherwise the false result is displayed. if this doesn't help please write back explaining (preferably with an example) what you are trying to accomplish here.
# Document 373: BM25 Score - 6.249743575484591
# hello brian mcm, welcome to the skype community. are you referring to sending sms message using your android device? if so, please be informed that we haven’t built this functionality on android device yet. for the meantime, use your desktop device in sending sms. hope this information helps us. let me know if you need further assistance. thank you.
# Document 260: BM25 Score - 6.0750374130020885
# context menu is embedded to thesoftware and items found on the context menu are not located in the same place in the registry. to better assist you, we suggest you to post your inquiry onthis link.
# Document 246: BM25 Score - 5.4746491752626945
# hello, when you go to bing.com, hover over images in the top menu. select "image favorites" to view the images you've saved. when viewing images, on the right hand side you will see stream and favorites beneath the image menu. hover your cursor over stream and favorites to view the menu. select image favorites.
#
# Follow Up
#
# Document 10: BM25 Score - 20.177997696600535
# what is the charms menu
# Document 1208: BM25 Score - 10.811610051638063
# the new skype .. reduced functionality
# Document 541: BM25 Score - 10.409271190010443
# where is the menu on skype?
# Document 1476: BM25 Score - 8.619382085646498
# how do i add the convert functionality that allows latex to the equation editor in word 2016?
# Document 1869: BM25 Score - 8.020398469458124
# bing picture of the day
#
#
#
# Query  11 : Best practices for backup in Windows 10 on an HP x360 laptop.
# Document 9: BM25 Score - 10.1255494116124
# msi support http://www.msi.com/index.php?func=service msi - downloads (bios and drivers) http://www.msi.com/index.php?func=downloadindex msi - forums http://forum-en.msi.com/ msi - service http://us.msi.com/index.php?func=service msi - live update on-line http://www.msi.com/index.php?func=downloadindex msi - contacts - set to north america - usa http://www.msi.com/index.php?func=html&name=aboutus hope this helps. -------------------------------------------------------------------------------------------- rob brown - microsoft mvp <- profile - windows and devices for it : bicycle - mark twain said it right.
# Document 427: BM25 Score - 9.85176669954436
# hi , this is sarah from the microsoft community. lets see if we can get your problem resolved. since the computer already comes with a valid license for windows 7, i would just perform a factory reset and set it up with a new user account. new computers that come preinstalled with windows often have what is called a recovery partition. this is used to reinstall the operating system in the event of a system crash. to access it, you will need to boot into when you start your computer by pressing a function key. this can be either f1, f2, f9, f10, f11, f12 or even del or tab key. consult the owners manual that came with your pc for instructions about how to reinstall windows. this is how the recovery partition is accessed for the most popular makes.. for dell, press ctrl + f11 directly after powering up the unit for hp, press f11 directly after powering up the unit for lg, press f11 directly after powering up the unit for toshiba, press and hold '0' before and during the power up for acer, press and hold alt + f10 as soon as you see the logo for asus, press f9 as soon as you see the asus logo. for samsung, press f4 at power up.. for fujitsu, press the f8 key repeatedly directly after powering up for advent, restart your computer. then press f10 repeatedly until the message "starting system recovery" is displayed for sony vaio, restart and press "f8" or "f10" repeatedly until the "advanced boot options" screen appears. if you want to run something newer than windows 7, you might still be able to get windows 10 for free: https://www.groovypost.com/howto/download-windows-10-free/ best, andresarah windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
# Document 15: BM25 Score - 9.508170813203803
# hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 23: BM25 Score - 9.450626618422746
# hey marissa, please take into account, you are running an outdated windows insider build 16251. microsoft released 16299 today. your options are, downloading the latest windows 10 insider iso, perform a repair upgrade, then proceed to upgrade to 16299. https://answers.microsoft.com/en-us/insider/wiki/insider_wintp-insider_install/how-to-install-the-latest-windows-10-insider-build/d8c389ae-31c4-42a2-97df-4815d82dd2b6 or revert to a stable release such as windows 10 1703 by performing a downgrade. step 1: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/how-to-download-official-windows-10-iso-files/35cde7ec-5b6f-481c-a02d-dadf465df326 step 2: http://answers.microsoft.com/en-us/insider/wiki/insider_wintp-insider_install/how-to-do-a-custom-installation-of-windows/38adfa8c-32f8-4354-8c53-13b5f2cf7e44 best, andremartin windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
# Document 107: BM25 Score - 8.768988615027745
# ...
# Document 14: BM25 Score - 10.05769541912559
# hi, the slow or unresponsive performance of windows 10 may be due to a third-party program or other factors like outdated drivers and system issues. for us to better assist you, we would like to ask for additional information. please answer the following: we hope to hear from you soon.
# Document 353: BM25 Score - 8.088443263359563
# you are welcome. @@@@@@@@@@@@@@@@@@ if you do want to try 10 again on that machine follow these steps to clean install 10: find the windows 10 media creation tool on the software download page "start fresh with a clean installation of windows 10" https://www.microsoft.com/en-us/software-download/windows10startfresh "how to clean install windows 10" http://www.tenforums.com/tutorials/1950-windows-10-clean-install.html ________________________________________________ when your free upgrade to 10 was originally activated microsoft will have kept the hardware configuration details of your device on their servers for recognition purposes if you have to reinstall 10. "activation in windows 10" (digital entitlement) https://support.microsoft.com/en-au/help/12440/windows-10-activation cheers.
# Document 15: BM25 Score - 7.598459897625273
# hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 427: BM25 Score - 6.680444045199
# hi , this is sarah from the microsoft community. lets see if we can get your problem resolved. since the computer already comes with a valid license for windows 7, i would just perform a factory reset and set it up with a new user account. new computers that come preinstalled with windows often have what is called a recovery partition. this is used to reinstall the operating system in the event of a system crash. to access it, you will need to boot into when you start your computer by pressing a function key. this can be either f1, f2, f9, f10, f11, f12 or even del or tab key. consult the owners manual that came with your pc for instructions about how to reinstall windows. this is how the recovery partition is accessed for the most popular makes.. for dell, press ctrl + f11 directly after powering up the unit for hp, press f11 directly after powering up the unit for lg, press f11 directly after powering up the unit for toshiba, press and hold '0' before and during the power up for acer, press and hold alt + f10 as soon as you see the logo for asus, press f9 as soon as you see the asus logo. for samsung, press f4 at power up.. for fujitsu, press the f8 key repeatedly directly after powering up for advent, restart your computer. then press f10 repeatedly until the message "starting system recovery" is displayed for sony vaio, restart and press "f8" or "f10" repeatedly until the "advanced boot options" screen appears. if you want to run something newer than windows 7, you might still be able to get windows 10 for free: https://www.groovypost.com/howto/download-windows-10-free/ best, andresarah windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
# Document 23: BM25 Score - 6.604872608181557
# hey marissa, please take into account, you are running an outdated windows insider build 16251. microsoft released 16299 today. your options are, downloading the latest windows 10 insider iso, perform a repair upgrade, then proceed to upgrade to 16299. https://answers.microsoft.com/en-us/insider/wiki/insider_wintp-insider_install/how-to-install-the-latest-windows-10-insider-build/d8c389ae-31c4-42a2-97df-4815d82dd2b6 or revert to a stable release such as windows 10 1703 by performing a downgrade. step 1: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/how-to-download-official-windows-10-iso-files/35cde7ec-5b6f-481c-a02d-dadf465df326 step 2: http://answers.microsoft.com/en-us/insider/wiki/insider_wintp-insider_install/how-to-do-a-custom-installation-of-windows/38adfa8c-32f8-4354-8c53-13b5f2cf7e44 best, andremartin windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
#
# Follow Up
#
# Document 50: BM25 Score - 11.319743837499015
# windows 10 is hanging my pc!!
# Document 863: BM25 Score - 10.026620403165387
# windows 10 skype app - changing language
# Document 1690: BM25 Score - 8.824948093601911
# problems with windows 10 calendar
# Document 56: BM25 Score - 8.631613135566099
# adobe flash update with windows 10.
# Document 1720: BM25 Score - 8.269289695407473
# get me back to windows 10 without bing!
#
#
#
# Query  49 : Fixing encrypted USB drive issues after Windows 10 update.
# Document 2: BM25 Score - 13.386332050378714
# we appreciate your response. your concern about connectivity issues can be due to software conflicts related to the specified program that you're using. the specified application installs usb drivers and lists a number of items to consider when using usb as your preferred private branch exchange (pbx) setting. this may have brought changes to the configuration of the usb ports that led to conflicts on your device. we'd recommend performing a clean boot in windows to isolate software conflicts on your device. to do this, you can perform the steps posted on this link. in the clean boot environment, check if you'll still experience connectivity issues when using the application along with the 3g dongle. the link will also provide steps to isolate the possible cause of the issue. once you're done troubleshooting, check the how to reset the computer to start normally after clean boot troubleshooting section to revert your device to normal boot. in the event that you'll still experience your concern, we'd recommend performing the following to assist in identifying application specific issues: we look forward to an update on your concern.
# Document 14: BM25 Score - 11.53680203366241
# hi, the slow or unresponsive performance of windows 10 may be due to a third-party program or other factors like outdated drivers and system issues. for us to better assist you, we would like to ask for additional information. please answer the following: we hope to hear from you soon.
# Document 12: BM25 Score - 10.26205209122147
# hi, windows 10 creators update requires a hard disk space of at least 16 gb for a 32-bit operating system or 20 gb for a 64-bit operating system. if your storage space is not enough to install windows 10 creators update, you can try freeing some drive space. here’s a link that would walk you through the steps on how to free up drive space in windows 10. we launch updates to add new features and ensure that your system is working efficiently. you can schedule update using active hours in windows 10. however, we have yet to include the option to decline or stop the update. we recommend that you post your suggestion to our feedback hub by following the steps below: 1. type “feedback hub” in cortana search and launch the app. 2. navigate to feedback in the left menu and press + add new feedback. 3. select the problem, and share any details you think are relevant, and choose an appropriate category and subcategory. 4. important: if possible, reproduce the problem(s) after clicking begin monitoring (or start capture) near the end of the form; stop monitoring when you’re done. 5. once you’ve completed the form and monitoring, click submit. 6. click continue using feedback hub. 7. click my feedback at the top, and then find the item you submitted (it may take a while to appear). 8. open the item you submitted and click share. 9. click copy link, then paste the link here in your response (it will look like https://aka.ms/<unique link>) you can visit this link for the instruction on how to set active hours in windows 10. let us know if you need additional assistance.
# Document 108: BM25 Score - 9.476289699094815
# since the drive is apparently full you need to do some emergency cleanup. windows has been traditionally very "cranky" when it is low on drive space. and it's definition of low has been based on percentage free, rather than absolute values. which now leads to the ludicrous situation where windows starts complaining about low drive space even with 10's or hundreds of gb, (yes gb) of free space. start by typing diskclean in the start menu. this will locate the built in hard drive cleanup tool. this will help you delete unneeded files. here are a couple of articles on using the tool http://www.techrepublic.com/article/how-to-clean-up-system-files-with-the-windows-10-disk-cleanup-tool/ https://www.howtogeek.com/256594/how-to-enable-hidden-options-in-windows-disk-cleanup-tool/
# Document 427: BM25 Score - 8.358792239441632
# hi , this is sarah from the microsoft community. lets see if we can get your problem resolved. since the computer already comes with a valid license for windows 7, i would just perform a factory reset and set it up with a new user account. new computers that come preinstalled with windows often have what is called a recovery partition. this is used to reinstall the operating system in the event of a system crash. to access it, you will need to boot into when you start your computer by pressing a function key. this can be either f1, f2, f9, f10, f11, f12 or even del or tab key. consult the owners manual that came with your pc for instructions about how to reinstall windows. this is how the recovery partition is accessed for the most popular makes.. for dell, press ctrl + f11 directly after powering up the unit for hp, press f11 directly after powering up the unit for lg, press f11 directly after powering up the unit for toshiba, press and hold '0' before and during the power up for acer, press and hold alt + f10 as soon as you see the logo for asus, press f9 as soon as you see the asus logo. for samsung, press f4 at power up.. for fujitsu, press the f8 key repeatedly directly after powering up for advent, restart your computer. then press f10 repeatedly until the message "starting system recovery" is displayed for sony vaio, restart and press "f8" or "f10" repeatedly until the "advanced boot options" screen appears. if you want to run something newer than windows 7, you might still be able to get windows 10 for free: https://www.groovypost.com/howto/download-windows-10-free/ best, andresarah windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
#
# Follow Up
#
# Document 51: BM25 Score - 16.187245788860096
# encrpyted usb drive no longer working after windows 10 update
# Document 62: BM25 Score - 12.42573994388602
# reinstalling windows 10 after total hard drive failure
# Document 1214: BM25 Score - 10.818667367218879
# is there a usb to ata/atapi bridge driver for windows rt
# Document 37: BM25 Score - 10.617073985262598
# windows 10 failed at usb reset, now what?
# Document 1425: BM25 Score - 9.720313277316771
# re-install word 2010 after hard drive replace--no product key
#
#
#
# Query  50 : Resolving desktop stuck and never loading issues in Windows 10.
# Document 409: BM25 Score - 9.791449662461034
# hi thomas, thank you for the update on the issue and good to hear that your issue is resolved by following the steps provided. we really appreciate your efforts and time which you spent on resolving the issue. this information will benefit other community members to solve their similar issues. in addition to that, you are always welcome to post your queries on microsoft community forum. we'll be glad to assist you again. regards,
# Document 485: BM25 Score - 9.002947951960252
# there are some known issues between older version of mac os (such as sierra 10.12.x) and ms office. can you please try to upgrade your os to high sierra? https://support.apple.com/macos/high-sierra please let usknow if this helps. ciao and thanks james
# Document 452: BM25 Score - 8.997873956184625
# skypebrowserhost.exe is a component of skype for windows desktop application which consolidates internet related operations in separate processes. all crash reports show that skypebrowserhost.exe is crashing on jscript9.dll component. jscript9.dll is javascript component used when scripting is conducted using internet explorer. jscript9.dll is updated whenever internet explorer is updated. the version of internet explorer (ie11) installed on your computer is about 2 years old and needs to be updated. open windows update tool and make sure that all missing/pending updates, incl. updates for internet explorer are installed.
# Document 271: BM25 Score - 7.727722100690103
# hi tammy, welcome to skype community! what version of skype are you using, is it the skype for windows 10 version or the classic skype for windows desktop version? if you are using the skype for windows 10 version, please test if the issue will be similar when you're using the classic version. the classic skype for windows desktop version can be downloaded at this link: click here. i am looking forward to your response. regards,
# Document 23: BM25 Score - 7.33413488376993
# hey marissa, please take into account, you are running an outdated windows insider build 16251. microsoft released 16299 today. your options are, downloading the latest windows 10 insider iso, perform a repair upgrade, then proceed to upgrade to 16299. https://answers.microsoft.com/en-us/insider/wiki/insider_wintp-insider_install/how-to-install-the-latest-windows-10-insider-build/d8c389ae-31c4-42a2-97df-4815d82dd2b6 or revert to a stable release such as windows 10 1703 by performing a downgrade. step 1: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/how-to-download-official-windows-10-iso-files/35cde7ec-5b6f-481c-a02d-dadf465df326 step 2: http://answers.microsoft.com/en-us/insider/wiki/insider_wintp-insider_install/how-to-do-a-custom-installation-of-windows/38adfa8c-32f8-4354-8c53-13b5f2cf7e44 best, andremartin windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
#
# Follow Up
#
# Document 52: BM25 Score - 19.115180418340806
# desktop gets stuck and never loads.
# Document 65: BM25 Score - 15.817893816199932
# windows store stuck on downloading
# Document 1169: BM25 Score - 10.79344505541224
# camera stuck showing my desktop not me!
# Document 392: BM25 Score - 10.464742615695164
# skype account sign in - continous loading, never loads
# Document 1200: BM25 Score - 9.173752950383939
# skype mac 10.9.5 desktop cookies delima

# %% [markdown]
# # Query-likelihood with dirichlet smoothing

# %%
import math
from collections import Counter

class QueryLikelihoodModel:
    def __init__(self, corpus, mu=2000):
        self.corpus = corpus
        self.mu = mu
        self.term_frequencies = [Counter(doc) for doc in corpus]
        self.document_lengths = [len(doc) for doc in corpus]
        self.collection_size = sum(self.document_lengths)

    def dirichlet_smoothed_score(self, query, document):
        score = 0
        doc_length = len(document)

        for term in query:
            term_frequency = document.count(term)
            collection_frequency = sum(doc_freq[term] for doc_freq in self.term_frequencies)
            background_prob = collection_frequency / self.collection_size

            smoothed_term_prob = (term_frequency + self.mu * background_prob) / (doc_length + self.mu)
            # Add a small constant to avoid log(0)
            smoothed_term_prob = max(smoothed_term_prob, 1e-10)
            score += math.log(smoothed_term_prob)

        return score

    def rank_documents(self, query):
        scores = [(doc_index, self.dirichlet_smoothed_score(query, self.corpus[doc_index])) for doc_index in range(len(self.corpus))]
        ranked_docs = sorted(scores, key=lambda x: x[1], reverse=True)
        return ranked_docs


corpus = list(potential_answer.values())
ql_model = QueryLikelihoodModel(corpus)
ql_follow_up = QueryLikelihoodModel(titles_clean)
i=1
for query in queries:
  print('Query ', i, ':', query)
  query = [word.lower() for word in query.split()]
  ranked_documents = ql_model.rank_documents(query)
  ql_a[i] = [i for i, s in ranked_documents[:5]]
  for index, score in ranked_documents[:5]:
      print(f"Document {index + 1}: Query Likelihood Score - {score}")
      print(corpus[index])
  print('\nFollow Up\n')
  follow_up_documents = ql_follow_up.rank_documents(query)
  ql_f[i] = [i for i, s in follow_up_documents[:5]]
  for index, score in follow_up_documents[:5]:
    print(f"Document {index + 1}: Query Likelihood Score - {score}")
    print(titles_clean[index])
  print('\n\n')
  i+=1
# Below are the 50 queries with top 5 relevant documents displayed using Query-likelihood Model
# Followed by this is the set of potential follow up queries the user can select as the next question in a conversation
# Out:
# Query  1 : Why does 'backgroundtaskhost.exe' stop working?
# Document 430: Query Likelihood Score - -84.04922746363727
# hi paul, welcome to the skype community forum. i know how important it is for you to use the 4.17.135 skype version. however, we have fully stopped supporting this version and upgraded the app to 4.18.15 and that's the reason why you're getting the same error message all over again. we always recommend to use the latest version of skype for the best possible experience. there are few reasons why you should update your application(s): i hope this helps. kindly let us know if you have questions. regards, rhiza_emonica
# Document 25: Query Likelihood Score - -84.72884225426135
# hi denise, there are several possible reasons why you are unable to send an email in outlook.com. it can be because the message or attachments are too large or your inbox is full. for information and steps on how to resolve the issue with sending emails in outlook.com, you can refer to the article on this link. to stop or cancel an email that you are sending, you can check the steps provided in hansv mvp's post by clicking this link. if you have other questions, don't hesitate to reach out. regards.
# Document 285: Query Likelihood Score - -84.83386346282802
# i have discovered an answer. it is microsoft and bing with the issue. i experimented with substituting the "user agent" in the browsers. i tested several variations: also tested the following: so, the actual browser used doesn't make a difference, just what browser it claims to be when communicating with bing. it looks like microsoft and bing are "browser sniffing" opera and either purposefully or accidentally sending a different bing search webpage. why am i not surprised? for now i'm using the same user agent switching add-ons i used for testing so i can function with bing search. it is a work-around that i shouldn't have to use.
# Document 141: Query Likelihood Score - -84.9264211595965
# instead of drag and drop, try using the insert>picture>picture from file... command. my guess is that latexit is producing non-standard files that the powerpoint 2016 for mac import filter is having trouble parsing. you can also click on the small smiley-face icon in the upper-right corner of the program window, choose tell us what can be better and describe the problem in detail. submitting sends the report to the mac programmers. there are no apple os x tablets, only ios ones. there are many styluses (styli?) made for the ipad, there's no reason why you can't use one with powerpoint mobile for ipad. office 2016 for mac is compatible with windows versions. that means the files can be opened in windows, that doesn't mean it has exactly the same features.
# Document 13: Query Likelihood Score - -85.01557635203433
# once you have installed a new update, it will replace the existing dll files that help run the operating system. installing an update means that you will have a new build which comes with new features and functionalities. this also means that some of the features and functionalities from the old build is no longer available. here’s an article that talks about the new features that comes with the windows 10 creators update. a new update does not add additional storage space. 20 gb is the minimum amount of space that the new update would consume once you successfully installed it. that is the reason why it is required to have at least 20 gb of free storage space for a 64-bit operating system before installing the update. you can visit this link for the information about the system requirements and other important details. if you have other questions, feel free to reach out to us.
#
# Follow Up
#
# Document 575: Query Likelihood Score - -83.01713412962455
# why does the size function in bing image search not work any more? in fact, why does bing image search really stink these days?
# Document 281: Query Likelihood Score - -83.6780683921224
# (office 2016 macos): pdf paste into a powerpoint slide doesn't work but in word it does. why?
# Document 2097: Query Likelihood Score - -84.31405498557477
# why doesn't my bing swagcode work?
# Document 2080: Query Likelihood Score - -84.31700121738672
# why is the set goal link not working?
# Document 2124: Query Likelihood Score - -84.32971830596613
# why did bing stop the name scheme (bing image id)?
#
#
#
# Query  2 : How to improve system performance and maintenance for Microsoft Edge on Windows 10?
# Document 135: Query Likelihood Score - -152.64734935589817
# hello antonio, thank you for the update on this issue. i suggest you the following link to know more about microsoft account and computer specific microsoft account verification refer to the link to know about microsoft account and its configuration. get the new account created by following the article. ensure to get the microsoft account verified on your computer. refer to the link to verify your computer for microsoft account. after creating new user account please try to install all pending updates after running dism (checksur.exe). run the system update readiness tool (checksur.exe) download and run the system update readiness tool. this tool runs a one-time scan for inconsistencies that may prevent future servicing operations. for more information about how to download and run the checksur.exe tool, click the following article number to view the article in the microsoft knowledge base. please follow the steps to install available windows updates. after installing all the pending updates, please try to run dism windows image scan and restore health command. following are the steps: if issue still persists please reply with the details of the troubleshooting steps with the result. hope the information helps. let us know if you need further assistance with windows related issues, we’ll be glad to assist you.
# Document 352: Query Likelihood Score - -164.91771338330875
# hi, you can reinstall 8 again from your recovery media that you made before the upgrade. microsoft has ended support and downloads for 8. you do have to do a reinstall of 8/8.1 @@@@@@@@@@@@@@@@@@@@@ if you never made the windows 8 recovery media read this: do a clean install of the exact same edition of 8.1 as 8 is. windows 8 > 8.1 is a free upgrade released by microsoft. @@@@@@@@@@@@@@@@@@@@@@@@@@ you can download and create your own windows 8.1 installation media to reinstall the operating system with.. "create installation media for windows 8.1" http://windows.microsoft.com/en-us/windows-8/create-reset-refresh-media "download windows 8.1" https://www.microsoft.com/en-us/software-download/windows8 a similar tutorial which may also assist you "create installation media for windows 8.1" http://winsupersite.com/windows-8/create-installation-media-windows-81 in the first screen of this very simple wizard, you need to choose the following: language. english – en-us if you're in the united states. edition. windows 8.1 (core), windows 8.1 n, windows 8.1 pro, windows 8.1 pro n, or windows 8.1 single language. architecture. 64-bit (x64 ) or 32-bit (x86). _______________________________________ "how to create a bootable usb or dvd with a windows 8 or 8.1 iso" http://www.eightforums.com/tutorials/2227-create-bootable-usb-dvd-windows-8-iso.html warning _____________________________________ how to clean install: "how to do a clean install of windows 8 or windows 8.1" http://www.eightforums.com/tutorials/2299-clean-install-windows-8-a.html make sure that you read section 4 _____________________________________ with windows 8/8.1 the product key on preinstalled operating systems (hp, acer, etc) is embedded in the bios in the motherboard, so that the lost and/or worn c.o.a. sticker problem is no more. when you reinstall it will pick up the product key and activate the system automatically. if it does not, follow these steps: "how to activate windows 8 and 8.1 by phone" http://www.eightforums.com/tutorials/24636-activate-windows-8-phone.html "get help with activation errors" http://windows.microsoft.com/en-us/windows-8/activation-errors "how to activate a microsoft product by using microsoft product activation center" http://support.microsoft.com/kb/950929/en-us _______________________________________________ if you do wish to/need to keep a record of it: "windows 10 embedded product key tool" https://neosmart.net/blog/2014/windows-10-embedded-product-key-tool/ "we’re proud to introduce the immediate release of our newest utility for windows users: the neosmart technologies embedded product key tool. designed for users of windows 7, windows 8, and windows 10, our embedded product key tool will retrieve and display the windows setup product key embedded in the bios or efi, allowing you to store it for safe-keeping or use it to reinstall windows with an official windows setup image." you can also use: "belarc advisor - free personal pc audit (version 8.5c)" http://www.belarc.com/free_download.html or: "product keyfinder" https://www.magicaljellybean.com/keyfinder/ cheers. this will not work to install windows 8 or 8.1 for uefi. for that, see this tutorial below instead. uefi bootable usb flash drive - create in windows
# Document 15: Query Likelihood Score - -165.38337651598263
# hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 343: Query Likelihood Score - -166.61857798896614
# hi, check with acer support as their could known issues. acer - usa - service and support - drivers http://us.acer.com/acer/service.do?languageisoctxparam=en&ctx2.c2att1=25&countryisoctxparam=us&ctx1g.c2att92=447&ctx1.att21k=1&crc=3618978704 acer - worldwide http://www.acer.com/worldwide/selection.html the acer site shows a bluetooth driver for vista but not windows 7 so it must use the default windows 7 drivers or is not supported - check with acer support. for the driver info go here and check extenze then select 4620 - be sure in middle of page to select the windows version you want to know about. http://us.acer.com/acer/service.do?languageisoctxparam=en&miu10einu24.current.attn2b2f2eef=3750&sp=page15e&ctx2.c2att1=25&miu10ekcond13.attn2b2f2eef=3750&countryisoctxparam=us&ctx1g.c2att92=453&ctx1.att21k=1&crc=2054404012 ===================================== troubleshooting : hardware devices not detected or not working - a mr fixit http://support.microsoft.com/gp/hardware_device_problems add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer set up a bluetooth enabled device http://windows.microsoft.com/en-us/windows-vista/set-up-a-bluetooth-enabled-device troubleshoot problems with bluetooth enabled devices http://windows.microsoft.com/en-us/windows-vista/troubleshoot-problems-with-bluetooth-enabled-devices how to setup a bluetooth connection http://www.wintuts.com/how-to-setup-a-bluetooth-connection the bluetooth item in control panel on a windows vista sp2-based computer does not work as expected when you click the item - for windows 7 check this manually http://support.microsoft.com/kb/960531/en-us if you need drivers try your system maker's support site and/or the actual device maker's site. bluetoothview is a small utility that runs in the background, and monitor the activity of bluetooth devices around you. for each detected bluetooth device, it displays the following information: device name, bluetooth address, major device type, minor device type, first detection time, last detection time, and more. bluetoothview can also notify you when a new bluetooth device is detected, by displaying a balloon in your taskbar or by playing a small beep sound. - free http://www.nirsoft.net/utils/bluetooth_viewer.html bluetoothcl is a small console application that dumps all current detected bluetooth devices into the standard output. for each bluetooth device, the following information is displayed: mac address, name, major device type, minor device type, and optionally the company name of the device (if external file of mac addresses - oui.txt is provided) - free http://www.nirsoft.net/utils/bluetoothcl.html bluetoothlogview is a small utility that monitors the activity of bluetooth devices around you, and displays a log of bluetooth devices on the main window. every time that a new bluetooth device arrives to your area and when the device leaves your area, a new log line is added with the following information: device name, device address, event time, event type ('device arrival' or 'device left'), device type, and the company that created the device. bluetoothlogview also allows you to specify a description for every device (according to its mac address) that will appear under the 'description' column. - free http://www.nirsoft.net/utils/bluetooth_log_view.html --------------------------------------------------------------------- change settings for a bluetooth enabled device http://windows.microsoft.com/en-us/windows7/change-settings-for-a-bluetooth-enabled-device add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer add a bluetooth or other wireless or network device: frequently asked questions http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-or-other-wireless-or-network-device-frequently-asked-questions ---------------------------------------------- ...
# Document 134: Query Likelihood Score - -167.2614645655464
# hello antonio, thank you for posting your query on microsoft community. as per your description, i understand that the two iwdaud devices load over and over again and it impact the running applications including mozilla firefox. i will certainly help you with the issue. 1. have you recently made any changes on your computer, prior to the issue? 2. which forum suggested you that the issue is related with kb3022345? 3. is there any windows update which has been failed recently? as of now, i recommend you to go through following methods: method 1: please put the computer in clean boot mode and check if you are getting the error message. boot the computer in a clean boot state and check the status. a clean boot helps to verify if any third party application service or startup item is causing this issue. note: after you have finished troubleshooting, follow steps under “how to reset the computer to start as usual after troubleshooting with clean boot” in the article to boot to normal startup. if issue persists, scan your computer using sfc scan to fix the possible corruption of windows system components. method 2: i would suggest you to perform sfc scan and check if that helps. the sfc/scannow command scans all protected system files and replaces incorrect versions with correct microsoft versions. note: system file checker is a utility in windows that allows users to scan for corruptions in windows system files and restore corrupted files. if issue continues, please reply with the details and the screenshot of the error message. refer the link for how to include a screenshot in your post hope this information is helpful. please do let us know if you need further assistance with windows, we’ll be glad to assist you.
#
# Follow Up
#
# Document 2: Query Likelihood Score - -176.21554954086696
# windows 10 microsoft edge is slow - system performance and maintenance
# Document 787: Query Likelihood Score - -219.29148207264527
# 2 questions about skype for android: (1) how to add phonebook entry and (2) how to edit a phonebook entry
# Document 31: Query Likelihood Score - -221.10219891055465
# windows 10 update stucks at 89% and details shows "update for windows 10 for x64-based systems (kb3141032) error"
# Document 499: Query Likelihood Score - -222.30297452065773
# microsoft edge on windows 7 and 8.1?
# Document 420: Query Likelihood Score - -222.44096439667604
# windows 8.1 setting picture positions for individual pictures in desktop background slideshow
#
#
#
# Query  3 : Troubleshooting start menu issues in Windows 10.
# Document 12: Query Likelihood Score - -80.70808218381407
# hi, windows 10 creators update requires a hard disk space of at least 16 gb for a 32-bit operating system or 20 gb for a 64-bit operating system. if your storage space is not enough to install windows 10 creators update, you can try freeing some drive space. here’s a link that would walk you through the steps on how to free up drive space in windows 10. we launch updates to add new features and ensure that your system is working efficiently. you can schedule update using active hours in windows 10. however, we have yet to include the option to decline or stop the update. we recommend that you post your suggestion to our feedback hub by following the steps below: 1. type “feedback hub” in cortana search and launch the app. 2. navigate to feedback in the left menu and press + add new feedback. 3. select the problem, and share any details you think are relevant, and choose an appropriate category and subcategory. 4. important: if possible, reproduce the problem(s) after clicking begin monitoring (or start capture) near the end of the form; stop monitoring when you’re done. 5. once you’ve completed the form and monitoring, click submit. 6. click continue using feedback hub. 7. click my feedback at the top, and then find the item you submitted (it may take a while to appear). 8. open the item you submitted and click share. 9. click copy link, then paste the link here in your response (it will look like https://aka.ms/<unique link>) you can visit this link for the instruction on how to set active hours in windows 10. let us know if you need additional assistance.
# Document 2: Query Likelihood Score - -81.64377173826182
# we appreciate your response. your concern about connectivity issues can be due to software conflicts related to the specified program that you're using. the specified application installs usb drivers and lists a number of items to consider when using usb as your preferred private branch exchange (pbx) setting. this may have brought changes to the configuration of the usb ports that led to conflicts on your device. we'd recommend performing a clean boot in windows to isolate software conflicts on your device. to do this, you can perform the steps posted on this link. in the clean boot environment, check if you'll still experience connectivity issues when using the application along with the 3g dongle. the link will also provide steps to isolate the possible cause of the issue. once you're done troubleshooting, check the how to reset the computer to start normally after clean boot troubleshooting section to revert your device to normal boot. in the event that you'll still experience your concern, we'd recommend performing the following to assist in identifying application specific issues: we look forward to an update on your concern.
# Document 107: Query Likelihood Score - -94.76827649212858
# hi , this is joseph from the microsoft community. lets see if we can get your problem resolved. apps might be available in different locations depending on your version of windows 10. in windows 10 1607 and earlier, you can find your apps by opening start > settings > system > apps and features. in windows 10 1703 and later, you can ind your apps by opening start > settings > apps > apps and features. select the app then click uninstall. for legacy apps, you can open programs and features press windows key + r type: appwiz.cpl hit enter select the application you want to uninstall then click change/uninstall n the command bar. if your computer supports an sd card reader, you can install one, then move some windows store apps to the sd card to free upgrade. here are some other ways you can free up space in windows 10: http://answers.microsoft.com/en-us/windows/wiki/windows_10-win_upgrade/how-to-free-up-disk-space-in-windows/2458cc31-bd19-482f-ace5-7e3bd9da8098 and you can also use a free third party program such as treesize to find whats eating up space. https://www.groovypost.com/howto/map-hardrive-usage-find-hidden-files-windows-10-treesize-freeware/ best, andrejoseph windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
# Document 15: Query Likelihood Score - -94.8306976767036
# hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 134: Query Likelihood Score - -95.2153534780812
# hello antonio, thank you for posting your query on microsoft community. as per your description, i understand that the two iwdaud devices load over and over again and it impact the running applications including mozilla firefox. i will certainly help you with the issue. 1. have you recently made any changes on your computer, prior to the issue? 2. which forum suggested you that the issue is related with kb3022345? 3. is there any windows update which has been failed recently? as of now, i recommend you to go through following methods: method 1: please put the computer in clean boot mode and check if you are getting the error message. boot the computer in a clean boot state and check the status. a clean boot helps to verify if any third party application service or startup item is causing this issue. note: after you have finished troubleshooting, follow steps under “how to reset the computer to start as usual after troubleshooting with clean boot” in the article to boot to normal startup. if issue persists, scan your computer using sfc scan to fix the possible corruption of windows system components. method 2: i would suggest you to perform sfc scan and check if that helps. the sfc/scannow command scans all protected system files and replaces incorrect versions with correct microsoft versions. note: system file checker is a utility in windows that allows users to scan for corruptions in windows system files and restore corrupted files. if issue continues, please reply with the details and the screenshot of the error message. refer the link for how to include a screenshot in your post hope this information is helpful. please do let us know if you need further assistance with windows, we’ll be glad to assist you.
#
# Follow Up
#
# Document 43: Query Likelihood Score - -99.52492238814303
# windows 10 start menu
# Document 1066: Query Likelihood Score - -113.64755807987353
# can't see any menu options (no menu bar across top of app) in skype for windows 10 !!!
# Document 61: Query Likelihood Score - -114.2694291805499
# windows start up time setting display
# Document 272: Query Likelihood Score - -114.3089130553873
# skype issues following upgrade to version 7.40.0.103 for windows
# Document 1625: Query Likelihood Score - -114.33062605728799
# when i right click on my desktop it takes forever to open the menu in windows 7
#
#
#
# Query  4 : Fixing screen sketch problems.
# Document 1: Query Likelihood Score - -61.850008826567105
# hi, windows is open to new ideas. your feedback is highly appreciated and will help us to improve our ability to serve you and other users of screen sketch. you can always submit your suggestions using the windows feedback hub. when you submit a feedback item, we gather additional details and information about your issue that will help our engineers address it. feedback items regularly receive microsoft responses on the submissions in the feedback app so you can see what we are doing about your feedback. you can either submit a new feedback or upvote an existing feedback item by following the steps provided on this link. feel free to get back to us if we can help you with anything else.
# Document 186: Query Likelihood Score - -75.82826431919382
# hi, let me ask you; i would suggest you to provide more details regarding the issue you’re facing. please see the article provided below, which will guide you on how to ask questions. suggestions for asking a question on help forums also, i would request you to post us back with a screen shot of the issue, so that we can help you better. you can refer to the following article to include a screenshot to your post. how to include a screenshot in your post please revert to this response along with answers to questions asked, we will be glad to help you further.
# Document 160: Query Likelihood Score - -75.83409750703461
# hi kristen, thanks for sharing your experience with us. regarding this issue, please change the file extension name from ppt into pptx to check whether you can open the file. meanwhile, please share more details with us if the issue persist: 1) right click the file on your mac and choose get info to capture a screenshot about the properties of this file. 2) how did you save your changes after you first open it? 3) capture a screenshot about the error message. 4) go to powerpoint > about powerpoint to capture a screenshot about the product information. regards, williamdiane
# Document 393: Query Likelihood Score - -76.09819022586018
# hi , to connect your computer to a television, your computer needs to have a video port that matches one of the inputs on your television. if your television does not have a vga or dvi input that matches an output on your computer, you will need to use composite video or s-video cables. if your computer doesn't have any of these tv-compatible outputs, then you might be able to install a new video card that has the right connection. you will need a hdmi cable to connect tv with laptop. follow these steps to connect your computer to your tv: 1. turn off your computer and position it within easy reach of your tv. disconnect the monitor, but leave the mouse and keyboard connected. 2. connect the appropriate video cable from your computer's output to your tv. 3. turn on your tv and set it to the input that matches the output on your computer. you might need to refer to the user's guide included with your tv for instructions on how to do this. 4. turn on your computer. you should see windows displayed on your tv. if the screen looks stretched, or part of the screen seems cut off, you probably need to adjust the screen resolution in windows. http://windows.microsoft.com/en-us/windows7/getting-the-best-display-on-your-monitor if you can't see windows on your tv, you might need to reconnect the computer to your monitor and adjust the screen resolution before you connect to your tv. http://windows.microsoft.com/en-us/windows7/connect-your-computer-to-a-tv http://windows.microsoft.com/en-us/windows7/hdtv-frequently-asked-questions check the display settings. follow these steps: 1. click start and click control panel and then click on personalization. 2. click on display settings. 3. under display settings click the settings tab. 4. then select the 2nd monitor display from the drop down under display. 5. put a checkmark against “extend my windows desktop onto this monitor”. 6. click on apply and then click the advanced button. 7. click the graphics card tab that is installed on the computer, for example, intel graphics media accelerator, and then click the graphics properties button under advanced. 8. next, under the display devices select television as single display and under multiple display select primary device as television and secondary device as notebook or laptop. 9. click on ok on all the windows to close the display properties. regards, afzaclairerosoft support. visit our microsoft answers feedback forum and let us know what you think.
# Document 58: Query Likelihood Score - -76.11983896176112
# hello, would you mind posting a screenshot of the window? upload it in your next reply using the insert image icon in the menu above. it is next to the last icon on the right. which browser are you using? which windows version? i'm unable to reproduce the issue. how to take a screenshot.
#
# Follow Up
#
# Document 4: Query Likelihood Score - -61.27340744067142
# screen sketch issue
# Document 1661: Query Likelihood Score - -76.04546199162326
# each morning my screen is blck and computer does not start unless i disconnect and blindly on a blck screen put my password
# Document 388: Query Likelihood Score - -76.68493421546117
# share screen
# Document 60: Query Likelihood Score - -76.68592726420216
# screen flicker
# Document 583: Query Likelihood Score - -76.68741499073492
# share screen view
#
#
#
# Query  5 : Dealing with high CPU usage by 'remsh.exe' in the task manager.
# Document 491: Query Likelihood Score - -140.4984820221238
# i'd start with task manager. press control + alt + delete and click task manager. the various tabs in taskman will show you which programs/processes/services are eating the most memory and cpu time. i'd first check the performance tab and click memory to make sure that nothing's eating all or most all of available memory, then go to the processes tab and click cpu to sort the list from highest to lowest percentage. look for processes that are eating lots of cpu time.
# Document 306: Query Likelihood Score - -170.88170310165123
# hi, thank you for posting your query in microsoft community. i can imagine the inconvenience you are experiencing and will certainly help you in the right direction to fix the issue. however, i would appreciate if you could answer a few questions to narrow down the issue in order to provide you with better assistance. as per the issue description the space of your hdd get used up and no free space remains there even though you have limited apps installed. so, it seems that the issue is related to the hdd. i would suggest you to try the steps provided below and see if it helps you to fix the issue. method 1: step 1: run disk clean up first, i suggest you to run windows disk cleanup tool to clean your hard disk from all unnecessary files that might be causing this issue on your computer. you may refer the steps in the article below to run disk clean up: http://windows.microsoft.com/en-us/windows/delete-files-using-disk-cleanup#delete-files-using-disk-cleanup=windows-8 step 2: perform disk check after successfully running disk cleanup tool, also run check disk to check the hard disk for errors if any and automatically repair them. note: the root drive has to be c: and the command may schedule a task at the system startup, if it does, then press y to schedule a task and restart the computer to perform chkdsk. important:while performing chkdsk on the hard drive if any bad sectors are found on the hard drive when chkdsk tries to repair that sector if any data available on that might be lost method 2:run memory diagnostics i would also suggest you to run windows memory diagnostics utility. windows 8.1 includes built-in features to help you identify and diagnose problems with memory. refer to the steps below: method 3: run a malware scan the microsoft safety scanner is a free downloadable security tool that provides on-demand scanning and helps remove viruses, spyware, and other malicious software. it works with your existing antivirus software. kindly follow the below steps to run the microsoft safety scanner. important:any data files that are infected may only be cleaned by deleting the file entirely, which means there is a potential for data loss. note: the microsoft safety scanner expires 10 days after being downloaded. to rerun a scan with the latest anti-malware definitions, download and run the microsoft safety scanner again. hope this will fix the issue, if not let us know with the updated status and we will be happy to assist you further. regards,
# Document 314: Query Likelihood Score - -171.82524680152704
# hi michael, welcome to the skype community forum. i do understand the inconvenience you have faced. let me help you on this. there’s probably an issue with the internet connection (yours or the person you’re calling), or with your device. let's resolve this by following the steps below: important: if you’d like to keep your chat and call history, skip this step. *by default, the library folder is hidden in mac os x v10.7 “lion” and higher. to find your library folder, open finder and, from the menu bar, select go, press and hold the option key, and then select library. please let us know if you have other questions. regards, rhiza_eryan
# Document 343: Query Likelihood Score - -172.5283835983519
# hi, check with acer support as their could known issues. acer - usa - service and support - drivers http://us.acer.com/acer/service.do?languageisoctxparam=en&ctx2.c2att1=25&countryisoctxparam=us&ctx1g.c2att92=447&ctx1.att21k=1&crc=3618978704 acer - worldwide http://www.acer.com/worldwide/selection.html the acer site shows a bluetooth driver for vista but not windows 7 so it must use the default windows 7 drivers or is not supported - check with acer support. for the driver info go here and check extenze then select 4620 - be sure in middle of page to select the windows version you want to know about. http://us.acer.com/acer/service.do?languageisoctxparam=en&miu10einu24.current.attn2b2f2eef=3750&sp=page15e&ctx2.c2att1=25&miu10ekcond13.attn2b2f2eef=3750&countryisoctxparam=us&ctx1g.c2att92=453&ctx1.att21k=1&crc=2054404012 ===================================== troubleshooting : hardware devices not detected or not working - a mr fixit http://support.microsoft.com/gp/hardware_device_problems add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer set up a bluetooth enabled device http://windows.microsoft.com/en-us/windows-vista/set-up-a-bluetooth-enabled-device troubleshoot problems with bluetooth enabled devices http://windows.microsoft.com/en-us/windows-vista/troubleshoot-problems-with-bluetooth-enabled-devices how to setup a bluetooth connection http://www.wintuts.com/how-to-setup-a-bluetooth-connection the bluetooth item in control panel on a windows vista sp2-based computer does not work as expected when you click the item - for windows 7 check this manually http://support.microsoft.com/kb/960531/en-us if you need drivers try your system maker's support site and/or the actual device maker's site. bluetoothview is a small utility that runs in the background, and monitor the activity of bluetooth devices around you. for each detected bluetooth device, it displays the following information: device name, bluetooth address, major device type, minor device type, first detection time, last detection time, and more. bluetoothview can also notify you when a new bluetooth device is detected, by displaying a balloon in your taskbar or by playing a small beep sound. - free http://www.nirsoft.net/utils/bluetooth_viewer.html bluetoothcl is a small console application that dumps all current detected bluetooth devices into the standard output. for each bluetooth device, the following information is displayed: mac address, name, major device type, minor device type, and optionally the company name of the device (if external file of mac addresses - oui.txt is provided) - free http://www.nirsoft.net/utils/bluetoothcl.html bluetoothlogview is a small utility that monitors the activity of bluetooth devices around you, and displays a log of bluetooth devices on the main window. every time that a new bluetooth device arrives to your area and when the device leaves your area, a new log line is added with the following information: device name, device address, event time, event type ('device arrival' or 'device left'), device type, and the company that created the device. bluetoothlogview also allows you to specify a description for every device (according to its mac address) that will appear under the 'description' column. - free http://www.nirsoft.net/utils/bluetooth_log_view.html --------------------------------------------------------------------- change settings for a bluetooth enabled device http://windows.microsoft.com/en-us/windows7/change-settings-for-a-bluetooth-enabled-device add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer add a bluetooth or other wireless or network device: frequently asked questions http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-or-other-wireless-or-network-device-frequently-asked-questions ---------------------------------------------- ...
# Document 244: Query Likelihood Score - -172.5988034596495
# hello daniel, the problem that you are experiencing with the bottom taskbar in powerpoint 2016 is possibly caused by a 3rd party add-ins. to better assist you, we suggest that you try to disable all 3rd party add-ins or run powerpoint in safe mode and verify the result. you can also repair the powerpoint app by going to this link. let us know how it goes.
#
# Follow Up
#
# Document 5: Query Likelihood Score - -176.3412775235901
# remsh.exe started to appear in my task manager and to have high cpu usage
# Document 520: Query Likelihood Score - -190.0126531108194
# image name ( the name of the process) is missing in task manager. no option to select "image name" column again?
# Document 1064: Query Likelihood Score - -190.6601072671413
# does anyone else have issues with the "invisible" status going back to online by itself?
# Document 1537: Query Likelihood Score - -191.67552429562946
# high cpu usage when using a different account
# Document 1439: Query Likelihood Score - -205.05781461907543
# is there a cpu meter app for windows 10 similar to the cpu meter gadget for windows 7?
#
#
#
# Query  6 : Steps to remove Skype for Business from Windows 10.
# Document 306: Query Likelihood Score - -111.3099628473739
# hi, thank you for posting your query in microsoft community. i can imagine the inconvenience you are experiencing and will certainly help you in the right direction to fix the issue. however, i would appreciate if you could answer a few questions to narrow down the issue in order to provide you with better assistance. as per the issue description the space of your hdd get used up and no free space remains there even though you have limited apps installed. so, it seems that the issue is related to the hdd. i would suggest you to try the steps provided below and see if it helps you to fix the issue. method 1: step 1: run disk clean up first, i suggest you to run windows disk cleanup tool to clean your hard disk from all unnecessary files that might be causing this issue on your computer. you may refer the steps in the article below to run disk clean up: http://windows.microsoft.com/en-us/windows/delete-files-using-disk-cleanup#delete-files-using-disk-cleanup=windows-8 step 2: perform disk check after successfully running disk cleanup tool, also run check disk to check the hard disk for errors if any and automatically repair them. note: the root drive has to be c: and the command may schedule a task at the system startup, if it does, then press y to schedule a task and restart the computer to perform chkdsk. important:while performing chkdsk on the hard drive if any bad sectors are found on the hard drive when chkdsk tries to repair that sector if any data available on that might be lost method 2:run memory diagnostics i would also suggest you to run windows memory diagnostics utility. windows 8.1 includes built-in features to help you identify and diagnose problems with memory. refer to the steps below: method 3: run a malware scan the microsoft safety scanner is a free downloadable security tool that provides on-demand scanning and helps remove viruses, spyware, and other malicious software. it works with your existing antivirus software. kindly follow the below steps to run the microsoft safety scanner. important:any data files that are infected may only be cleaned by deleting the file entirely, which means there is a potential for data loss. note: the microsoft safety scanner expires 10 days after being downloaded. to rerun a scan with the latest anti-malware definitions, download and run the microsoft safety scanner again. hope this will fix the issue, if not let us know with the updated status and we will be happy to assist you further. regards,
# Document 111: Query Likelihood Score - -111.51196709115918
# hello christopher, we appreciate the information you have provided with regards to customer's concern. hi bedrishahsarahwilson, welcome to skype community! the information provided by ruwim.bchristopher is correct. also, you can access your account in skype in any devices as long as it is supported and system requirements are met. to manage your video settings on the skype preview uwp, please follow below steps: 1. click on your profile icon > settings. 2. under audio & video settings, change video using the drop-down box, toggle on to run a test video. 3. under calling settings, toggle allow calls from everyone to on. what's new in skype for windows 10? hope this information helps us. let me know if you need further assistance. regards.
# Document 314: Query Likelihood Score - -114.97154763453094
# hi michael, welcome to the skype community forum. i do understand the inconvenience you have faced. let me help you on this. there’s probably an issue with the internet connection (yours or the person you’re calling), or with your device. let's resolve this by following the steps below: important: if you’d like to keep your chat and call history, skip this step. *by default, the library folder is hidden in mac os x v10.7 “lion” and higher. to find your library folder, open finder and, from the menu bar, select go, press and hold the option key, and then select library. please let us know if you have other questions. regards, rhiza_eryan
# Document 15: Query Likelihood Score - -124.3032505588476
# hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 242: Query Likelihood Score - -124.8941516727107
# hello christina r. pain management, welcome to skype community forum. in my experience, skype is best when using a windows desktop or laptop (i’m not sure for other skype users). you can do free skype-to-skype calls and video calls. you can also start group video calling with your family, friends and colleagues. and it is also free! instant messaging is also possible and free of charge. group chat is also available. you can do screen sharing with your colleagues and this is also free. you can also call mobile number, you need to have a skype credit or a calling subscription with this. there are also paid services that skype offers, however skype is designed for personal use only. you may want to check skype for business for you to use it for your business. let me know if this information helps. please do not hesitate to reply to this thread if you need further help.
#
# Follow Up
#
# Document 6: Query Likelihood Score - -114.83989729193497
# how can i remove skype for business from windows 10?
# Document 989: Query Likelihood Score - -144.93067525518862
# skype for 'windows desk top' and 'windows 10'
# ...
# Document 343: Query Likelihood Score - -144.81139450673044
# hi, check with acer support as their could known issues. acer - usa - service and support - drivers http://us.acer.com/acer/service.do?languageisoctxparam=en&ctx2.c2att1=25&countryisoctxparam=us&ctx1g.c2att92=447&ctx1.att21k=1&crc=3618978704 acer - worldwide http://www.acer.com/worldwide/selection.html the acer site shows a bluetooth driver for vista but not windows 7 so it must use the default windows 7 drivers or is not supported - check with acer support. for the driver info go here and check extenze then select 4620 - be sure in middle of page to select the windows version you want to know about. http://us.acer.com/acer/service.do?languageisoctxparam=en&miu10einu24.current.attn2b2f2eef=3750&sp=page15e&ctx2.c2att1=25&miu10ekcond13.attn2b2f2eef=3750&countryisoctxparam=us&ctx1g.c2att92=453&ctx1.att21k=1&crc=2054404012 ===================================== troubleshooting : hardware devices not detected or not working - a mr fixit http://support.microsoft.com/gp/hardware_device_problems add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer set up a bluetooth enabled device http://windows.microsoft.com/en-us/windows-vista/set-up-a-bluetooth-enabled-device troubleshoot problems with bluetooth enabled devices http://windows.microsoft.com/en-us/windows-vista/troubleshoot-problems-with-bluetooth-enabled-devices how to setup a bluetooth connection http://www.wintuts.com/how-to-setup-a-bluetooth-connection the bluetooth item in control panel on a windows vista sp2-based computer does not work as expected when you click the item - for windows 7 check this manually http://support.microsoft.com/kb/960531/en-us if you need drivers try your system maker's support site and/or the actual device maker's site. bluetoothview is a small utility that runs in the background, and monitor the activity of bluetooth devices around you. for each detected bluetooth device, it displays the following information: device name, bluetooth address, major device type, minor device type, first detection time, last detection time, and more. bluetoothview can also notify you when a new bluetooth device is detected, by displaying a balloon in your taskbar or by playing a small beep sound. - free http://www.nirsoft.net/utils/bluetooth_viewer.html bluetoothcl is a small console application that dumps all current detected bluetooth devices into the standard output. for each bluetooth device, the following information is displayed: mac address, name, major device type, minor device type, and optionally the company name of the device (if external file of mac addresses - oui.txt is provided) - free http://www.nirsoft.net/utils/bluetoothcl.html bluetoothlogview is a small utility that monitors the activity of bluetooth devices around you, and displays a log of bluetooth devices on the main window. every time that a new bluetooth device arrives to your area and when the device leaves your area, a new log line is added with the following information: device name, device address, event time, event type ('device arrival' or 'device left'), device type, and the company that created the device. bluetoothlogview also allows you to specify a description for every device (according to its mac address) that will appear under the 'description' column. - free http://www.nirsoft.net/utils/bluetooth_log_view.html --------------------------------------------------------------------- change settings for a bluetooth enabled device http://windows.microsoft.com/en-us/windows7/change-settings-for-a-bluetooth-enabled-device add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer add a bluetooth or other wireless or network device: frequently asked questions http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-or-other-wireless-or-network-device-frequently-asked-questions ---------------------------------------------- ...
# Document 3: Query Likelihood Score - -145.1190431387768
# you'll need to reinstall to uefi, booting the installation media as a uefi device to delete all partitions down to unallocated space to clear the formatting - as illustrated in the gold standard clean install here: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 this is worth it because then you'll have the full modern features of the bios-replacing uefi which offers better security, gui with mouse support, and other improvements. http://www.youtube.com/watch?v=drmivy7bil4 a legacy install should eventually be replaced with uefi. before reinstall enable uefi in bios, if necessary csm or legacy mode while you have an mbr drive still needing to boot, secure boot.. you may need to turn off fast boot if it won't pause long enough to boot the installation media when you power up pressing the dell f12 key. but after install turn fast boot on unless you need to boot media as you'll access bios via recovery settings .
#
# Follow Up
#
# Document 51: Query Likelihood Score - -130.26056204264637
# encrpyted usb drive no longer working after windows 10 update
# Document 62: Query Likelihood Score - -145.64137915742364
# reinstalling windows 10 after total hard drive failure
# Document 1519: Query Likelihood Score - -159.68340595138017
# microsoft 2010 excel not working after upgrade from windows 8 to windows 10
# Document 1649: Query Likelihood Score - -160.39096930576494
# unable to uninstall wild tangent game from windows 10 after upgrading from windows 8.
# Document 37: Query Likelihood Score - -161.0201605758166
# windows 10 failed at usb reset, now what?
#
#
#
# Query  50 : Resolving desktop stuck and never loading issues in Windows 10.
# Document 68: Query Likelihood Score - -150.12032749876752
# hello margaret, thank you for posting you query on microsoft community forums. as per description, you are unable to install the apps getting error message "something happened and your purchase can't be completed. error code: 0x800704d5 ". i would appreciate, if you can provide us the following information to help us understand the issue better? i would suggest you to follow the methods given below and check. method 1: make sure that the date and time are correct on the computer. a) check the setting for date/time by choosing the desktop tile and then left click on the date/time in the corner. b) click on change date and time settings. and then verify the time zone is correct as well as the internet time tab has the option to synchronize with internet time server. if issue still persists try method 2. method 2: clear the store cache you may try to clear the cache for the store and check if it helps: a) press the “windows logo” + “r” keys on the keyboard. b) type “wsreset.exe” and press “enter”. c) reboot the computer and then check the issues with the apps. if issue didn't get resolve try method 3. method 3: disable security software temporarily disable security software temporarily and check if the issue persists. disclaimer: antivirus software can help protect your computer against viruses and other security threats. in most cases, you should not disable your antivirus software. if you do have to temporarily disable it to install other software, you should re-enable it as soon as you're done. if you are connected to the internet or a network during the time your antivirus software is disabled, your computer is vulnerable to attacks. hope this information is helpful. please do let us know if you need further assistance with windows.
# Document 452: Query Likelihood Score - -150.34216568999202
# skypebrowserhost.exe is a component of skype for windows desktop application which consolidates internet related operations in separate processes. all crash reports show that skypebrowserhost.exe is crashing on jscript9.dll component. jscript9.dll is javascript component used when scripting is conducted using internet explorer. jscript9.dll is updated whenever internet explorer is updated. the version of internet explorer (ie11) installed on your computer is about 2 years old and needs to be updated. open windows update tool and make sure that all missing/pending updates, incl. updates for internet explorer are installed.
# Document 15: Query Likelihood Score - -162.29881255409083
# hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 107: Query Likelihood Score - -162.3417518851737
# hi , this is joseph from the microsoft community. lets see if we can get your problem resolved. apps might be available in different locations depending on your version of windows 10. in windows 10 1607 and earlier, you can find your apps by opening start > settings > system > apps and features. in windows 10 1703 and later, you can ind your apps by opening start > settings > apps > apps and features. select the app then click uninstall. for legacy apps, you can open programs and features press windows key + r type: appwiz.cpl hit enter select the application you want to uninstall then click change/uninstall n the command bar. if your computer supports an sd card reader, you can install one, then move some windows store apps to the sd card to free upgrade. here are some other ways you can free up space in windows 10: http://answers.microsoft.com/en-us/windows/wiki/windows_10-win_upgrade/how-to-free-up-disk-space-in-windows/2458cc31-bd19-482f-ace5-7e3bd9da8098 and you can also use a free third party program such as treesize to find whats eating up space. https://www.groovypost.com/howto/map-hardrive-usage-find-hidden-files-windows-10-treesize-freeware/ best, andrejoseph windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
# Document 12: Query Likelihood Score - -162.4303056089347
# hi, windows 10 creators update requires a hard disk space of at least 16 gb for a 32-bit operating system or 20 gb for a 64-bit operating system. if your storage space is not enough to install windows 10 creators update, you can try freeing some drive space. here’s a link that would walk you through the steps on how to free up drive space in windows 10. we launch updates to add new features and ensure that your system is working efficiently. you can schedule update using active hours in windows 10. however, we have yet to include the option to decline or stop the update. we recommend that you post your suggestion to our feedback hub by following the steps below: 1. type “feedback hub” in cortana search and launch the app. 2. navigate to feedback in the left menu and press + add new feedback. 3. select the problem, and share any details you think are relevant, and choose an appropriate category and subcategory. 4. important: if possible, reproduce the problem(s) after clicking begin monitoring (or start capture) near the end of the form; stop monitoring when you’re done. 5. once you’ve completed the form and monitoring, click submit. 6. click continue using feedback hub. 7. click my feedback at the top, and then find the item you submitted (it may take a while to appear). 8. open the item you submitted and click share. 9. click copy link, then paste the link here in your response (it will look like https://aka.ms/<unique link>) you can visit this link for the instruction on how to set active hours in windows 10. let us know if you need additional assistance.
#
# Follow Up
#
# Document 31: Query Likelihood Score - -167.39415988424355
# windows 10 update stucks at 89% and details shows "update for windows 10 for x64-based systems (kb3141032) error"
# Document 65: Query Likelihood Score - -167.9349627905896
# windows store stuck on downloading
# Document 1757: Query Likelihood Score - -168.05501052269045
# bing desktop messed up windows update a bit and won't change the wallpaper daily until i restart
# Document 976: Query Likelihood Score - -168.06453660483038
# whenever i log into my laptop i get a black screen and a task bar with just just a windows icon on it
# Document 52: Query Likelihood Score - -168.6300750903244
# desktop gets stuck and never loads.

# %% [markdown]
# # TF_IDF Vector Space Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Sample documents
documents = list(potential_answer.values())

# Step 1: Text Preprocessing
vectorizer = TfidfVectorizer(stop_words='english')
follow_up_vectorizer = TfidfVectorizer(stop_words='english')
# Step 2: Building the TF-IDF Matrix
tfidf_matrix = vectorizer.fit_transform(documents)
follow_up_tfidf_matrix = follow_up_vectorizer.fit_transform(titles)
j = 1
for query in queries:
  # Step 3: Query Representation
  query_vector = vectorizer.transform([query])
  follow_up_query_vector = follow_up_vectorizer.transform([query])

  # Step 4: Similarity Calculation
  cosine_similarities = cosine_similarity(query_vector, tfidf_matrix).flatten()
  follow_up_cosine_similarities = cosine_similarity(follow_up_query_vector, follow_up_tfidf_matrix).flatten()

  # Get document indices sorted by similarity
  sorted_indices = cosine_similarities.argsort()[::-1]
  follow_up_sorted_indices = follow_up_cosine_similarities.argsort()[::-1]

  # Print the most similar document
  print('Query ', j, ':', query)
  tf_a[j] = sorted_indices[:5]
  for i in sorted_indices[:5]:
    print('Document',i,': ', documents[i])
  print('')
  tf_f[j] = follow_up_sorted_indices[:5]
  for i in follow_up_sorted_indices[:5]:
    print('Document',i,': ', titles[i])
  print('\n\n')
  j+=1
# Out:
# Query  1 : Why does 'backgroundtaskhost.exe' stop working?
# Document 161 :  internet explorer is iexplorer.exe explorer.exe is the file manager
# Document 41 :  there is a backend issue and microsoft is working on it. no eta when it will be fixed.
# Document 134 :  hello antonio, thank you for the update on this issue. i suggest you the following link to know more about microsoft account and computer specific microsoft account verification refer to the link to know about microsoft account and its configuration. get the new account created by following the article. ensure to get the microsoft account verified on your computer. refer to the link to verify your computer for microsoft account. after creating new user account please try to install all pending updates after running dism (checksur.exe). run the system update readiness tool (checksur.exe) download and run the system update readiness tool. this tool runs a one-time scan for inconsistencies that may prevent future servicing operations. for more information about how to download and run the checksur.exe tool, click the following article number to view the article in the microsoft knowledge base. please follow the steps to install available windows updates. after installing all the pending updates, please try to run dism windows image scan and restore health command. following are the steps: if issue still persists please reply with the details of the troubleshooting steps with the result. hope the information helps. let us know if you need further assistance with windows related issues, we’ll be glad to assist you.
# Document 163 :  is it happening to a specific contact? i suggest you try this basic troubleshooting steps below for the meantime and check if issue persist. 1. uninstall and reinstall the skype application with the latest version. 2. clear cache and data before uninstalling skype. 3. try using a different connection. also, we advise skype users to use the new skype application on mobile devices with an android version of 6.0 or higher, as skype sometimes necessary to retire older versions of skype, and skype enabled devices. unsupported skype enabled devices, and platforms may experience problems with calls and chats, lost or dropped calls and instant messages, or could stop working completely. hope this information helps. thanks.
# Document 37 :  hi, we're aware of the issue and our engineers are working on it. for real-time updates, you may refer to this link. feel free to post us back if you need more assistance.
#
# Document 0 :  backgroundTaskHost.exe stopped working
# Document 1829 :  My MSN (Bing) Weather app stop working.
# Document 918 :  Skype.exe Application Error
# Document 1839 :  Bing not working !
# Document 672 :  skype not working
#
#
#
# Query  2 : How to improve system performance and maintenance for Microsoft Edge on Windows 10?
# Document 256 :  hi, when edge was introduced for the first time, i was one of the hopefuls that one day microsoft edge would somehow be released for windows 7 or windows 8 and 8.1 as well. unfortunately, since the edge browser is a built-in application on the new universal windows platform, it wouldn't be possible to install edge on windows 7. we suggest though that you relay this great idea to our developers via our feedback hub so they can look into this, and possibly consider the idea in the future. feel free to contact us if you need further assistance with windows.
# Document 14 :  hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 352 :  you are welcome. @@@@@@@@@@@@@@@@@@ if you do want to try 10 again on that machine follow these steps to clean install 10: find the windows 10 media creation tool on the software download page "start fresh with a clean installation of windows 10" https://www.microsoft.com/en-us/software-download/windows10startfresh "how to clean install windows 10" http://www.tenforums.com/tutorials/1950-windows-10-clean-install.html ________________________________________________ when your free upgrade to 10 was originally activated microsoft will have kept the hardware configuration details of your device on their servers for recognition purposes if you have to reinstall 10. "activation in windows 10" (digital entitlement) https://support.microsoft.com/en-au/help/12440/windows-10-activation cheers.
# Document 13 :  hi, the slow or unresponsive performance of windows 10 may be due to a third-party program or other factors like outdated drivers and system issues. for us to better assist you, we would like to ask for additional information. please answer the following: we hope to hear from you soon.
# Document 439 :  hi, resetting microsoft edge through powershell to correct the misbehavior of the program. before you reset microsoft edge through powershell, we strongly recommend that you perform a full backup and/or create a system restore point first. the steps in resetting microsoft edge through powershell are as follows. step 1 navigate on the following folder (replace %username with your own username.) and clear everything inside it: c:users\%usernameappdatalocalpackagesmicrosoft.microsoftedge_8wekyb3d8bbwe step 2 right-click on the start menu and choose “windows powershell (admin)”. copy and paste the following code inside powershell and press enter: get-appxpackage -allusers -name microsoft.microsoftedge | foreach {add-appxpackage -disabledevelopmentmode -register “$($_.installlocation)appxmanifest.xml” -verbose} when you open microsoft edge next time, you will see that it has been reset to default. if you encounter any error, type the following command to get the first few logged events: get-appxlog | out-gridview note the error code in the log and proceed here. check if the issue persists. regards.
#
# Document 1 :  Windows 10 Microsoft Edge is slow - System Performance and maintenance
# Document 498 :  Microsoft Edge on Windows 7 and 8.1?
# Document 676 :  Microsoft Edge
# Document 355 :  Microsoft Edge
# Document 1695 :  Microsoft Edge
#
#
#
# Query  3 : Troubleshooting start menu issues in Windows 10.
# Document 513 :  does the same happen if you unselect the option "start skype when i start windows" and start skype manually after windows has booted completely?
# Document 352 :  you are welcome. @@@@@@@@@@@@@@@@@@ if you do want to try 10 again on that machine follow these steps to clean install 10: find the windows 10 media creation tool on the software download page "start fresh with a clean installation of windows 10" https://www.microsoft.com/en-us/software-download/windows10startfresh "how to clean install windows 10" http://www.tenforums.com/tutorials/1950-windows-10-clean-install.html ________________________________________________ when your free upgrade to 10 was originally activated microsoft will have kept the hardware configuration details of your device on their servers for recognition purposes if you have to reinstall 10. "activation in windows 10" (digital entitlement) https://support.microsoft.com/en-au/help/12440/windows-10-activation cheers.
# Document 106 :  hi , this is joseph from the microsoft community. lets see if we can get your problem resolved. apps might be available in different locations depending on your version of windows 10. in windows 10 1607 and earlier, you can find your apps by opening start > settings > system > apps and features. in windows 10 1703 and later, you can ind your apps by opening start > settings > apps > apps and features. select the app then click uninstall. for legacy apps, you can open programs and features press windows key + r type: appwiz.cpl hit enter select the application you want to uninstall then click change/uninstall n the command bar. if your computer supports an sd card reader, you can install one, then move some windows store apps to the sd card to free upgrade. here are some other ways you can free up space in windows 10: http://answers.microsoft.com/en-us/windows/wiki/windows_10-win_upgrade/how-to-free-up-disk-space-in-windows/2458cc31-bd19-482f-ace5-7e3bd9da8098 and you can also use a free third party program such as treesize to find whats eating up space. https://www.groovypost.com/howto/map-hardrive-usage-find-hidden-files-windows-10-treesize-freeware/ best, andrejoseph windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
# Document 14 :  hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 422 :  you can have two different skype applications installed on a windows 10 computer. microsoft skype for windows 10 (skype uwp). https://support.skype.com/en/faq/fa34664/finding-your-way-around-skype-for-windows-10?platform=uwp the currently latest version of this skype uwp application is 11.19.856.0, and this is the one you are using now. you may also install and use the classic skype for windows desktop, https://support.skype.com/en/faq/fa11099/how-do-i-find-my-way-around-skype-for-windows-desktop the currently latest version of this skype application is 7.40.x.103 and can be installed/updated using this link: http://www.skype.com/go/getskype-full you have received the update email because you have previously used a version of the classic skype that was older than 7.31. note that you can use both skype applications on windows 10 computer, but not simultaneously. if you start one, the other will close.
#
# Document 42 :  Windows 10 Start Menu
# Document 2 :  Start Menu
# Document 1065 :  CAN'T SEE ANY MENU OPTIONS (NO MENU BAR ACROSS TOP OF APP) IN SKYPE FOR WINDOWS 10 !!!
# Document 540 :  Where is the menu on skype?
# Document 686 :  windows 10
#
#
#
# Query  4 : Fixing screen sketch problems.
# Document 114 :  hi, try this free revo uninstaller program to remove problem programs. http://www.revouninstaller.com/revo_uninstaller_free_download.html "how-to-use" instructions are included there: read information in tabs across the top. ______________________________ try this "fix-it" from microsoft for problems with uninstalling programs; http://support.microsoft.com/mats/program_install_and_uninstall/en _____________________________ and also scan for malware. download, install, update and scan your system with the free version of malwarebytes antimalware: http://www.malwarebytes.org/products/malwarebytes_free cheers. what it fixes... corrupted registry keys on 64-bit operating systems corrupted registry keys that control the update data problems that prevent new programs from being installed problems that prevent existing programs from being completely uninstalled or updated problems that block you from uninstalling a program through the add or remove programs (or programs and features) item in control panel
# Document 0 :  hi, windows is open to new ideas. your feedback is highly appreciated and will help us to improve our ability to serve you and other users of screen sketch. you can always submit your suggestions using the windows feedback hub. when you submit a feedback item, we gather additional details and information about your issue that will help our engineers address it. feedback items regularly receive microsoft responses on the submissions in the feedback app so you can see what we are doing about your feedback. you can either submit a new feedback or upvote an existing feedback item by following the steps provided on this link. feel free to get back to us if we can help you with anything else.
# Document 391 :  hi barbara, if you could not see any app related to the app which you have mentioned in the link mentioned by neha in the above post then you might need to install any third party application by searching from your favorite search engine. note: using third party software, including hardware drivers can cause serious problems that may prevent your computer from booting properly. microsoft cannot guarantee that any problems resulting from the use of third party software can be solved. using third party software is at your own risk. do keep us updated. regards,
# Document 475 :  since your screen shot suggests that you are using word for mac, i'm moving your question to the macword section.
# Document 291 :  hi, thank you for contacting microsoft community. please confirm what issues are you facing in converting ? is there is any error code ? for conversion tool i would suggest you to look for any third party conversion tool, use your favorite search engine and look for a software that suits your requirement using third party software, including hardware drivers can cause serious problems that may prevent your computer from booting properly. microsoft cannot guarantee that any problems resulting from the use of third party software can be solved. using third party software is at your own risk. hope this information helps. feel free to contact us again for further assistance.
#
# Document 3 :  Screen Sketch Issue
# Document 115 :  SKYPE PROBLEMS
# Document 1014 :  Skype Video Problems (Shares Screen)
# Document 701 :  video problems
# Document 899 :  Camera problems
#
#
#
# Query  5 : Dealing with high CPU usage by 'remsh.exe' in the task manager.
# Document 490 :  i'd start with task manager. press control + alt + delete and click task manager. the various tabs in taskman will show you which programs/processes/services are eating the most memory and cpu time. i'd first check the performance tab and click memory to make sure that nothing's eating all or most all of available memory, then go to the processes tab and click cpu to sort the list from highest to lowest percentage. look for processes that are eating lots of cpu time.
# Document 161 :  internet explorer is iexplorer.exe explorer.exe is the file manager
# Document 484 :  there are some known issues between older version of mac os (such as sierra 10.12.x) and ms office. can you please try to upgrade your os to high sierra? https://support.apple.com/macos/high-sierra please let usknow if this helps. ciao and thanks james
# Document 430 :  hi rick, this is john from the microsoft community. lets see if we can get your problem resolved. have you tried disabling all startup programs to see what happens? press windows key + x click task manager go to the startup tab, then disable all programs that are starting up with the system. its possible your antivirus utility might be scheduled to run at that time of the day, you could check its update settings to confirm. best, andrejohn windows insider mvp mvp-windows and devices for it http://twitter.com/adacosta
# Document 134 :  hello antonio, thank you for the update on this issue. i suggest you the following link to know more about microsoft account and computer specific microsoft account verification refer to the link to know about microsoft account and its configuration. get the new account created by following the article. ensure to get the microsoft account verified on your computer. refer to the link to verify your computer for microsoft account. after creating new user account please try to install all pending updates after running dism (checksur.exe). run the system update readiness tool (checksur.exe) download and run the system update readiness tool. this tool runs a one-time scan for inconsistencies that may prevent future servicing operations. for more information about how to download and run the checksur.exe tool, click the following article number to view the article in the microsoft knowledge base. please follow the steps to install available windows updates. after installing all the pending updates, please try to run dism windows image scan and restore health command. following are the steps: if issue still persists please reply with the details of the troubleshooting steps with the result. hope the information helps. let us know if you need further assistance with windows related issues, we’ll be glad to assist you.
#
# Document 4 :  remsh.exe started to appear in my Task Manager and to have high CPU usage
# Document 1536 :  High CPU usage when using a different account
# Document 726 :  High CPU load when using Powerpoint
# Document 981 :  Disk manager
# Document 519 :  Image name ( the name of the process) is missing in task manager. No option to select "image name" column again?
#
#
#
# Query  6 : Steps to remove Skype for Business from Windows 10.
# Document 352 :  you are welcome. @@@@@@@@@@@@@@@@@@ if you do want to try 10 again on that machine follow these steps to clean install 10: find the windows 10 media creation tool on the software download page "start fresh with a clean installation of windows 10" https://www.microsoft.com/en-us/software-download/windows10startfresh "how to clean install windows 10" http://www.tenforums.com/tutorials/1950-windows-10-clean-install.html ________________________________________________ when your free upgrade to 10 was originally activated microsoft will have kept the hardware configuration details of your device on their servers for recognition purposes if you have to reinstall 10. "activation in windows 10" (digital entitlement) https://support.microsoft.com/en-au/help/12440/windows-10-activation cheers.
# Document 241 :  hello christina r. pain management, welcome to skype community forum. in my experience, skype is best when using a windows desktop or laptop (i’m not sure for other skype users). you can do free skype-to-skype calls and video calls. you can also start group video calling with your family, friends and colleagues. and it is also free! instant messaging is also possible and free of charge. group chat is also available. you can do screen sharing with your colleagues and this is also free. you can also call mobile number, you need to have a skype credit or a calling subscription with this. there are also paid services that skype offers, however skype is designed for personal use only. you may want to check skype for business for you to use it for your business. let me know if this information helps. please do not hesitate to reply to this thread if you need further help.
# Document 422 :  you can have two different skype applications installed on a windows 10 computer. microsoft skype for windows 10 (skype uwp). https://support.skype.com/en/faq/fa34664/finding-your-way-around-skype-for-windows-10?platform=uwp the currently latest version of this skype uwp application is 11.19.856.0, and this is the one you are using now. you may also install and use the classic skype for windows desktop, https://support.skype.com/en/faq/fa11099/how-do-i-find-my-way-around-skype-for-windows-desktop the currently latest version of this skype application is 7.40.x.103 and can be installed/updated using this link: http://www.skype.com/go/getskype-full you have received the update email because you have previously used a version of the classic skype that was older than 7.31. note that you can use both skype applications on windows 10 computer, but not simultaneously. if you start one, the other will close.
# Document 61 :  welcome to skype community forum! may i know if you're making a skype to skype call or skype to mobile/landline numbers? may i know when did this issue started? may i know what skype application are you on? you may check the links below to identify if you're using the classic version of skype for windows desktop or the new skype version on windows 10 (skype uwp) application. classic version of skype: click here new skype version on windows 10 (skype uwp) application: click here let us know if you have any further questions or clarifications. thank you! hello anthonyackerman,
# Document 270 :  hi tammy, welcome to skype community! what version of skype are you using, is it the skype for windows 10 version or the classic skype for windows desktop version? if you are using the skype for windows 10 version, please test if the issue will be similar when you're using the classic version. the classic skype for windows desktop version can be downloaded at this link: click here. i am looking forward to your response. regards,
#
# Document 5 :  How can I remove Skype for BUSINESS from Windows 10?
# Document 1002 :  skype for windows 10
# Document 686 :  windows 10
# Document 47 :  Windows 10
# Document 580 :  Can I use Skype for Business if Im not a business customer?
#
#
#
# Query  7 : Resolving the error 'Something went wrong' during Windows 10 factory reset.
# Document 125 :  windows rt doesn't even have windows media player. you've likely posted in the wrong section.
# Document 352 :  you are welcome. @@@@@@@@@@@@@@@@@@ if you do want to try 10 again on that machine follow these steps to clean install 10: find the windows 10 media creation tool on the software download page "start fresh with a clean installation of windows 10" https://www.microsoft.com/en-us/software-download/windows10startfresh "how to clean install windows 10" http://www.tenforums.com/tutorials/1950-windows-10-clean-install.html ________________________________________________ when your free upgrade to 10 was originally activated microsoft will have kept the hardware configuration details of your device on their servers for recognition purposes if you have to reinstall 10. "activation in windows 10" (digital entitlement) https://support.microsoft.com/en-au/help/12440/windows-10-activation cheers.
# Document 237 :  wrong guess. the bottom margin was set to 185 mm
# Document 14 :  hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 282 :  hi, thanks for the reply. i would suggest you to try resetting both the browsers and then check if it helps: to reset mozilla firefox please refer to: https://support.mozilla.org/en-us/kb/refresh-firefox-reset-add-ons-and-settings?redirectlocale=en-us&redirectslug=reset-firefox-easily-fix-most-problems to reset opera browser: close all running instance of opera. go to the installation folder of opera:c:usersuser_nameappdataroamingoperaopera, provided that you have installed opera using the default settings. delete the operapref.ini file disclaimer: the reset browser settings feature might reset security settings or privacy settings that you added to the list of trusted sites. the reset browser settings feature might also reset parental control settings. we recommend that you note these sites before you use the reset browser settings feature. resetting browser isn't reversible, and all previous settings are lost after reset. if the issue still persist then this can be a browser issue and i would suggest you to open bing in internet explorer and check if it works fine if yes then please contact mozilla support or opera support for the better assistance.
#
# Document 6 :  Windows 10 factory reset error "Something Went Wrong" after selecting Language, Keyboard and Language.
# Document 76 :  I Can not Open My hot mail Message Something went wrong
# Document 36 :  Windows 10 failed at usb reset, now what?
# Document 1771 :  Windows 10 Mobile shows wrong map
# Document 47 :  Windows 10
#
#
#
# Query  8 : Fixing network setup issues on Windows.
# Document 351 :  hi, you can reinstall 8 again from your recovery media that you made before the upgrade. microsoft has ended support and downloads for 8. you do have to do a reinstall of 8/8.1 @@@@@@@@@@@@@@@@@@@@@ if you never made the windows 8 recovery media read this: do a clean install of the exact same edition of 8.1 as 8 is. windows 8 > 8.1 is a free upgrade released by microsoft. @@@@@@@@@@@@@@@@@@@@@@@@@@ you can download and create your own windows 8.1 installation media to reinstall the operating system with.. "create installation media for windows 8.1" http://windows.microsoft.com/en-us/windows-8/create-reset-refresh-media "download windows 8.1" https://www.microsoft.com/en-us/software-download/windows8 a similar tutorial which may also assist you "create installation media for windows 8.1" http://winsupersite.com/windows-8/create-installation-media-windows-81 in the first screen of this very simple wizard, you need to choose the following: language. english – en-us if you're in the united states. edition. windows 8.1 (core), windows 8.1 n, windows 8.1 pro, windows 8.1 pro n, or windows 8.1 single language. architecture. 64-bit (x64 ) or 32-bit (x86). _______________________________________ "how to create a bootable usb or dvd with a windows 8 or 8.1 iso" http://www.eightforums.com/tutorials/2227-create-bootable-usb-dvd-windows-8-iso.html warning _____________________________________ how to clean install: "how to do a clean install of windows 8 or windows 8.1" http://www.eightforums.com/tutorials/2299-clean-install-windows-8-a.html make sure that you read section 4 _____________________________________ with windows 8/8.1 the product key on preinstalled operating systems (hp, acer, etc) is embedded in the bios in the motherboard, so that the lost and/or worn c.o.a. sticker problem is no more. when you reinstall it will pick up the product key and activate the system automatically. if it does not, follow these steps: "how to activate windows 8 and 8.1 by phone" http://www.eightforums.com/tutorials/24636-activate-windows-8-phone.html "get help with activation errors" http://windows.microsoft.com/en-us/windows-8/activation-errors "how to activate a microsoft product by using microsoft product activation center" http://support.microsoft.com/kb/950929/en-us _______________________________________________ if you do wish to/need to keep a record of it: "windows 10 embedded product key tool" https://neosmart.net/blog/2014/windows-10-embedded-product-key-tool/ "we’re proud to introduce the immediate release of our newest utility for windows users: the neosmart technologies embedded product key tool. designed for users of windows 7, windows 8, and windows 10, our embedded product key tool will retrieve and display the windows setup product key embedded in the bios or efi, allowing you to store it for safe-keeping or use it to reinstall windows with an official windows setup image." you can also use: "belarc advisor - free personal pc audit (version 8.5c)" http://www.belarc.com/free_download.html or: "product keyfinder" https://www.magicaljellybean.com/keyfinder/ cheers. this will not work to install windows 8 or 8.1 for uefi. for that, see this tutorial below instead. uefi bootable usb flash drive - create in windows
# Document 342 :  hi, check with acer support as their could known issues. acer - usa - service and support - drivers http://us.acer.com/acer/service.do?languageisoctxparam=en&ctx2.c2att1=25&countryisoctxparam=us&ctx1g.c2att92=447&ctx1.att21k=1&crc=3618978704 acer - worldwide http://www.acer.com/worldwide/selection.html the acer site shows a bluetooth driver for vista but not windows 7 so it must use the default windows 7 drivers or is not supported - check with acer support. for the driver info go here and check extenze then select 4620 - be sure in middle of page to select the windows version you want to know about. http://us.acer.com/acer/service.do?languageisoctxparam=en&miu10einu24.current.attn2b2f2eef=3750&sp=page15e&ctx2.c2att1=25&miu10ekcond13.attn2b2f2eef=3750&countryisoctxparam=us&ctx1g.c2att92=453&ctx1.att21k=1&crc=2054404012 ===================================== troubleshooting : hardware devices not detected or not working - a mr fixit http://support.microsoft.com/gp/hardware_device_problems add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer set up a bluetooth enabled device http://windows.microsoft.com/en-us/windows-vista/set-up-a-bluetooth-enabled-device troubleshoot problems with bluetooth enabled devices http://windows.microsoft.com/en-us/windows-vista/troubleshoot-problems-with-bluetooth-enabled-devices how to setup a bluetooth connection http://www.wintuts.com/how-to-setup-a-bluetooth-connection the bluetooth item in control panel on a windows vista sp2-based computer does not work as expected when you click the item - for windows 7 check this manually http://support.microsoft.com/kb/960531/en-us if you need drivers try your system maker's support site and/or the actual device maker's site. bluetoothview is a small utility that runs in the background, and monitor the activity of bluetooth devices around you. for each detected bluetooth device, it displays the following information: device name, bluetooth address, major device type, minor device type, first detection time, last detection time, and more. bluetoothview can also notify you when a new bluetooth device is detected, by displaying a balloon in your taskbar or by playing a small beep sound. - free http://www.nirsoft.net/utils/bluetooth_viewer.html bluetoothcl is a small console application that dumps all current detected bluetooth devices into the standard output. for each bluetooth device, the following information is displayed: mac address, name, major device type, minor device type, and optionally the company name of the device (if external file of mac addresses - oui.txt is provided) - free http://www.nirsoft.net/utils/bluetoothcl.html bluetoothlogview is a small utility that monitors the activity of bluetooth devices around you, and displays a log of bluetooth devices on the main window. every time that a new bluetooth device arrives to your area and when the device leaves your area, a new log line is added with the following information: device name, device address, event time, event type ('device arrival' or 'device left'), device type, and the company that created the device. bluetoothlogview also allows you to specify a description for every device (according to its mac address) that will appear under the 'description' column. - free http://www.nirsoft.net/utils/bluetooth_log_view.html --------------------------------------------------------------------- change settings for a bluetooth enabled device http://windows.microsoft.com/en-us/windows7/change-settings-for-a-bluetooth-enabled-device add a bluetooth enabled device to your computer http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-enabled-device-to-your-computer add a bluetooth or other wireless or network device: frequently asked questions http://windows.microsoft.com/en-us/windows7/add-a-bluetooth-or-other-wireless-or-network-device-frequently-asked-questions ------------------------------ ...
# Document 180 :  since you mentioned that you are a computer programmer, we suggest that you post your query to our microsoft developers network (msdn) forum page, where the community members are more versed with the matter. there are programmers and developers who can provide the best solution for your concern. if there's anything else, feel free to let us know.
# Document 14 :  hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
# Document 441 :  hello david, thank you for providing us with the detailed description about the issue. i certainly understand the inconvenience caused to you. i will try to help you in fixing the issue. there is a possibility that this issue might have occurred either due to some “hardware or software” that have gone bad in the system or “system files” might have gone corrupt. in order to understand the issue more clearly, i would request you to kindly provide me with the following information. i would suggest you to follow the steps given below and check if it helps. step 1: please refer to the suggestions provided by “manuel souto pico” replied on february 29, 2012 in the microsoft community link http://answers.microsoft.com/en-us/windows/forum/windows_7-windows_programs/windows-disk-image-burner-has-disappeared-from/acbefb19-84d9-46c1-87a6-bd893b44f306 note: the steps in the above mentioned link also hold good for windows 8.1 if the issue still persists, follow step 2 step 2: i would suggest you to try using a different dvd and check if it fixes the issue. i hope this information is helpful. please do let us know if you need further assistance, we’ll be glad to assist you. thank you.
#
# Document 7 :  Network Setup issue
# Document 1559 :  network to xbox services on windows 8.1
# Document 195 :  network adapter driver problem in windows 7
# Document 1404 :  Issues with Table in Word.
# Document 841 :  Skype update issues for android
#
#
#
# Query  9 : Understanding the difference between legacy and UEFI in Dell E6420 BIOS.
# Document 2 :  you'll need to reinstall to uefi, booting the installation media as a uefi device to delete all partitions down to unallocated space to clear the formatting - as illustrated in the gold standard clean install here: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 this is worth it because then you'll have the full modern features of the bios-replacing uefi which offers better security, gui with mouse support, and other improvements. http://www.youtube.com/watch?v=drmivy7bil4 a legacy install should eventually be replaced with uefi. before reinstall enable uefi in bios, if necessary csm or legacy mode while you have an mbr drive still needing to boot, secure boot.. you may need to turn off fast boot if it won't pause long enough to boot the installation media when you power up pressing the dell f12 key. but after install turn fast boot on unless you need to boot media as you'll access bios via recovery settings .
# Document 319 :  hello michelle, welcome to skype community forum. can you try to reset your wi-fi and then please try to uninstall/reinstall the skype application, then try to check if there are any difference to online status of your skype contacts. we look forward to your reply. regards,
# Document 373 :  hello johncorks, welcome to skype community! my apology for the confusion. sending an sms message using the new skype for android is currently not available. for updates on when this feature will be available in the new skype for android, you can check this link from time to time. thank you for understanding. let us know if you need further assistance.
# Document 213 :  hi revant, sorry for the delayed response. for better understanding of the issue, please provide us following information: i suggest you to check the date and time of your tablet and set it to the correct value, as with the incorrect date and time your tablet might not be able to access the updates. hope this helps, get back to us with the required information and we will be glad to assist you.
# Document 411 :  hi bcposi54, based on my search, swf is not a format supported in powerpoint for mac. i don't find some official articles about directly adding swf file to powerpoint for mac. you may check our mvp matthew's suggestion or search for some other workarounds. meanwhile, you may also submit the feedback via powerpoint for mac uservoice. this is the best way to let the related team hear your voice. your feedback will help us perfect our products and services. thanks for your understanding. timvirginia
#
# Document 8 :  Legacy v UEFI - Dell E6420 BIOS
# Document 839 :  Skype (legacy) login issues
# Document 1237 :  What is the difference between answering a skype call as a phone call vs as a video call?
# Document 593 :  Power options- difference between turn off the display and put the computer to sleep?
# Document 436 :  dell 5110 random freezes
#
#
#
# Query  10 : Explaining the functionality of the charms menu in Windows.
# Document 372 :  hello brian mcm, welcome to the skype community. are you referring to sending sms message using your android device? if so, please be informed that we haven’t built this functionality on android device yet. for the meantime, use your desktop device in sending sms. hope this information helps us. let me know if you need further assistance. thank you.
# Document 351 :  hi, you can reinstall 8 again from your recovery media that you made before the upgrade. microsoft has ended support and downloads for 8. you do have to do a reinstall of 8/8.1 @@@@@@@@@@@@@@@@@@@@@ if you never made the windows 8 recovery media read this: do a clean install of the exact same edition of 8.1 as 8 is. windows 8 > 8.1 is a free upgrade released by microsoft. @@@@@@@@@@@@@@@@@@@@@@@@@@ you can download and create your own windows 8.1 installation media to reinstall the operating system with.. "create installation media for windows 8.1" http://windows.microsoft.com/en-us/windows-8/create-reset-refresh-media "download windows 8.1" https://www.microsoft.com/en-us/software-download/windows8 a similar tutorial which may also assist you "create installation media for windows 8.1" http://winsupersite.com/windows-8/create-installation-media-windows-81 in the first screen of this very simple wizard, you need to choose the following: language. english – en-us if you're in the united states. edition. windows 8.1 (core), windows 8.1 n, windows 8.1 pro, windows 8.1 pro n, or windows 8.1 single language. architecture. 64-bit (x64 ) or 32-bit (x86). _______________________________________ "how to create a bootable usb or dvd with a windows 8 or 8.1 iso" http://www.eightforums.com/tutorials/2227-create-bootable-usb-dvd-windows-8-iso.html warning _____________________________________ how to clean install: "how to do a clean install of windows 8 or windows 8.1" http://www.eightforums.com/tutorials/2299-clean-install-windows-8-a.html make sure that you read section 4 _____________________________________ with windows 8/8.1 the product key on preinstalled operating systems (hp, acer, etc) is embedded in the bios in the motherboard, so that the lost and/or worn c.o.a. sticker problem is no more. when you reinstall it will pick up the product key and activate the system automatically. if it does not, follow these steps: "how to activate windows 8 and 8.1 by phone" http://www.eightforums.com/tutorials/24636-activate-windows-8-phone.html "get help with activation errors" http://windows.microsoft.com/en-us/windows-8/activation-errors "how to activate a microsoft product by using microsoft product activation center" http://support.microsoft.com/kb/950929/en-us _______________________________________________ if you do wish to/need to keep a record of it: "windows 10 embedded product key tool" https://neosmart.net/blog/2014/windows-10-embedded-product-key-tool/ "we’re proud to introduce the immediate release of our newest utility for windows users: the neosmart technologies embedded product key tool. designed for users of windows 7, windows 8, and windows 10, our embedded product key tool will retrieve and display the windows setup product key embedded in the bios or efi, allowing you to store it for safe-keeping or use it to reinstall windows with an official windows setup image." you can also use: "belarc advisor - free personal pc audit (version 8.5c)" http://www.belarc.com/free_download.html or: "product keyfinder" https://www.magicaljellybean.com/keyfinder/ cheers. this will not work to install windows 8 or 8.1 for uefi. for that, see this tutorial below instead. uefi bootable usb flash drive - create in windows
# Document 69 :  it seems like the issue was with the third-party browser that you are using. you may also try to reset the settings of the third-party browser and check if the issue persists. for further assistance, kindly contact the software developer of your third-party browser so that they can check if there are possible incompatibility issues with certain websites and their functionality. let us know if you have any other concerns.
# Document 259 :  context menu is embedded to thesoftware and items found on the context menu are not located in the same place in the registry. to better assist you, we suggest you to post your inquiry onthis link.
# Document 231 :  i'm not quite following your question. the syntax for the if() function is: if(condition, true result, false result) so if the condition is true the true result is display otherwise the false result is displayed. if this doesn't help please write back explaining (preferably with an example) what you are trying to accomplish here.
#
# Document 9 :  What is the Charms menu
# Document 540 :  Where is the menu on skype?
# Document 1065 :  CAN'T SEE ANY MENU OPTIONS (NO MENU BAR ACROSS TOP OF APP) IN SKYPE FOR WINDOWS 10 !!!
# Document 42 :  Windows 10 Start Menu
# Document 1207 :  The new skype .. reduced functionality
#
#
#
# Query  11 : Best practices for backup in Windows 10 on an HP x360 laptop.
# ...
# Document 13 :  hi, the slow or unresponsive performance of windows 10 may be due to a third-party program or other factors like outdated drivers and system issues. for us to better assist you, we would like to ask for additional information. please answer the following: we hope to hear from you soon.
#
# Document 49 :  Windows 10 is hanging my PC!!
# Document 47 :  Windows 10
# Document 686 :  windows 10
# Document 1052 :  microsoft 365 excel hanging.
# Document 1719 :  Get me back to WIndows 10 without Bing!
#
#
#
# Query  49 : Fixing encrypted USB drive issues after Windows 10 update.
# Document 1 :  we appreciate your response. your concern about connectivity issues can be due to software conflicts related to the specified program that you're using. the specified application installs usb drivers and lists a number of items to consider when using usb as your preferred private branch exchange (pbx) setting. this may have brought changes to the configuration of the usb ports that led to conflicts on your device. we'd recommend performing a clean boot in windows to isolate software conflicts on your device. to do this, you can perform the steps posted on this link. in the clean boot environment, check if you'll still experience connectivity issues when using the application along with the 3g dongle. the link will also provide steps to isolate the possible cause of the issue. once you're done troubleshooting, check the how to reset the computer to start normally after clean boot troubleshooting section to revert your device to normal boot. in the event that you'll still experience your concern, we'd recommend performing the following to assist in identifying application specific issues: we look forward to an update on your concern.
# Document 352 :  you are welcome. @@@@@@@@@@@@@@@@@@ if you do want to try 10 again on that machine follow these steps to clean install 10: find the windows 10 media creation tool on the software download page "start fresh with a clean installation of windows 10" https://www.microsoft.com/en-us/software-download/windows10startfresh "how to clean install windows 10" http://www.tenforums.com/tutorials/1950-windows-10-clean-install.html ________________________________________________ when your free upgrade to 10 was originally activated microsoft will have kept the hardware configuration details of your device on their servers for recognition purposes if you have to reinstall 10. "activation in windows 10" (digital entitlement) https://support.microsoft.com/en-au/help/12440/windows-10-activation cheers.
# Document 107 :  since the drive is apparently full you need to do some emergency cleanup. windows has been traditionally very "cranky" when it is low on drive space. and it's definition of low has been based on percentage free, rather than absolute values. which now leads to the ludicrous situation where windows starts complaining about low drive space even with 10's or hundreds of gb, (yes gb) of free space. start by typing diskclean in the start menu. this will locate the built in hard drive cleanup tool. this will help you delete unneeded files. here are a couple of articles on using the tool http://www.techrepublic.com/article/how-to-clean-up-system-files-with-the-windows-10-disk-cleanup-tool/ https://www.howtogeek.com/256594/how-to-enable-hidden-options-in-windows-disk-cleanup-tool/
# Document 351 :  hi, you can reinstall 8 again from your recovery media that you made before the upgrade. microsoft has ended support and downloads for 8. you do have to do a reinstall of 8/8.1 @@@@@@@@@@@@@@@@@@@@@ if you never made the windows 8 recovery media read this: do a clean install of the exact same edition of 8.1 as 8 is. windows 8 > 8.1 is a free upgrade released by microsoft. @@@@@@@@@@@@@@@@@@@@@@@@@@ you can download and create your own windows 8.1 installation media to reinstall the operating system with.. "create installation media for windows 8.1" http://windows.microsoft.com/en-us/windows-8/create-reset-refresh-media "download windows 8.1" https://www.microsoft.com/en-us/software-download/windows8 a similar tutorial which may also assist you "create installation media for windows 8.1" http://winsupersite.com/windows-8/create-installation-media-windows-81 in the first screen of this very simple wizard, you need to choose the following: language. english – en-us if you're in the united states. edition. windows 8.1 (core), windows 8.1 n, windows 8.1 pro, windows 8.1 pro n, or windows 8.1 single language. architecture. 64-bit (x64 ) or 32-bit (x86). _______________________________________ "how to create a bootable usb or dvd with a windows 8 or 8.1 iso" http://www.eightforums.com/tutorials/2227-create-bootable-usb-dvd-windows-8-iso.html warning _____________________________________ how to clean install: "how to do a clean install of windows 8 or windows 8.1" http://www.eightforums.com/tutorials/2299-clean-install-windows-8-a.html make sure that you read section 4 _____________________________________ with windows 8/8.1 the product key on preinstalled operating systems (hp, acer, etc) is embedded in the bios in the motherboard, so that the lost and/or worn c.o.a. sticker problem is no more. when you reinstall it will pick up the product key and activate the system automatically. if it does not, follow these steps: "how to activate windows 8 and 8.1 by phone" http://www.eightforums.com/tutorials/24636-activate-windows-8-phone.html "get help with activation errors" http://windows.microsoft.com/en-us/windows-8/activation-errors "how to activate a microsoft product by using microsoft product activation center" http://support.microsoft.com/kb/950929/en-us _______________________________________________ if you do wish to/need to keep a record of it: "windows 10 embedded product key tool" https://neosmart.net/blog/2014/windows-10-embedded-product-key-tool/ "we’re proud to introduce the immediate release of our newest utility for windows users: the neosmart technologies embedded product key tool. designed for users of windows 7, windows 8, and windows 10, our embedded product key tool will retrieve and display the windows setup product key embedded in the bios or efi, allowing you to store it for safe-keeping or use it to reinstall windows with an official windows setup image." you can also use: "belarc advisor - free personal pc audit (version 8.5c)" http://www.belarc.com/free_download.html or: "product keyfinder" https://www.magicaljellybean.com/keyfinder/ cheers. this will not work to install windows 8 or 8.1 for uefi. for that, see this tutorial below instead. uefi bootable usb flash drive - create in windows
# Document 11 :  hi, windows 10 creators update requires a hard disk space of at least 16 gb for a 32-bit operating system or 20 gb for a 64-bit operating system. if your storage space is not enough to install windows 10 creators update, you can try freeing some drive space. here’s a link that would walk you through the steps on how to free up drive space in windows 10. we launch updates to add new features and ensure that your system is working efficiently. you can schedule update using active hours in windows 10. however, we have yet to include the option to decline or stop the update. we recommend that you post your suggestion to our feedback hub by following the steps below: 1. type “feedback hub” in cortana search and launch the app. 2. navigate to feedback in the left menu and press + add new feedback. 3. select the problem, and share any details you think are relevant, and choose an appropriate category and subcategory. 4. important: if possible, reproduce the problem(s) after clicking begin monitoring (or start capture) near the end of the form; stop monitoring when you’re done. 5. once you’ve completed the form and monitoring, click submit. 6. click continue using feedback hub. 7. click my feedback at the top, and then find the item you submitted (it may take a while to appear). 8. open the item you submitted and click share. 9. click copy link, then paste the link here in your response (it will look like https://aka.ms/<unique link>) you can visit this link for the instruction on how to set active hours in windows 10. let us know if you need additional assistance.
#
# Document 50 :  Encrpyted USB drive no longer working after windows 10 update
# Document 841 :  Skype update issues for android
# Document 1289 :  Windows 8.1 update
# Document 36 :  Windows 10 failed at usb reset, now what?
# Document 47 :  Windows 10
#
#
#
# Query  50 : Resolving desktop stuck and never loading issues in Windows 10.
# Document 352 :  you are welcome. @@@@@@@@@@@@@@@@@@ if you do want to try 10 again on that machine follow these steps to clean install 10: find the windows 10 media creation tool on the software download page "start fresh with a clean installation of windows 10" https://www.microsoft.com/en-us/software-download/windows10startfresh "how to clean install windows 10" http://www.tenforums.com/tutorials/1950-windows-10-clean-install.html ________________________________________________ when your free upgrade to 10 was originally activated microsoft will have kept the hardware configuration details of your device on their servers for recognition purposes if you have to reinstall 10. "activation in windows 10" (digital entitlement) https://support.microsoft.com/en-au/help/12440/windows-10-activation cheers.
# Document 270 :  hi tammy, welcome to skype community! what version of skype are you using, is it the skype for windows 10 version or the classic skype for windows desktop version? if you are using the skype for windows 10 version, please test if the issue will be similar when you're using the classic version. the classic skype for windows desktop version can be downloaded at this link: click here. i am looking forward to your response. regards,
# Document 408 :  hi thomas, thank you for the update on the issue and good to hear that your issue is resolved by following the steps provided. we really appreciate your efforts and time which you spent on resolving the issue. this information will benefit other community members to solve their similar issues. in addition to that, you are always welcome to post your queries on microsoft community forum. we'll be glad to assist you again. regards,
# Document 422 :  you can have two different skype applications installed on a windows 10 computer. microsoft skype for windows 10 (skype uwp). https://support.skype.com/en/faq/fa34664/finding-your-way-around-skype-for-windows-10?platform=uwp the currently latest version of this skype uwp application is 11.19.856.0, and this is the one you are using now. you may also install and use the classic skype for windows desktop, https://support.skype.com/en/faq/fa11099/how-do-i-find-my-way-around-skype-for-windows-desktop the currently latest version of this skype application is 7.40.x.103 and can be installed/updated using this link: http://www.skype.com/go/getskype-full you have received the update email because you have previously used a version of the classic skype that was older than 7.31. note that you can use both skype applications on windows 10 computer, but not simultaneously. if you start one, the other will close.
# Document 14 :  hello . i'm tara, an 8 year microsoft windows mvp, here to help you. 1) please work through this checklist to make sure the install is set up correctly, optimized for best performance, and any needed repairs are done: http://answers.microsoft.com/en-us/windows/wiki/windows_10-performance/windows-10-performance-and-install-integrity/75529fd4-fac7-4653-893a-dd8cd4b4db00 2) if any steps cannot be performed then try whichever method works to enter safe mode with networking which may work better to perform the steps: http://www.pcworld.com/article/2984712/windows/how-to-enter-windows-10s-safe-mode.html 3) if no safe mode, from the advanced startup options use the command prompt at boot to run the repair commands in the checklist: https://www.tenforums.com/tutorials/2294-advanced-startup-options-boot-windows-10-a.html 3) if nothing else works then you can reinstall windows while keeping your files, programs and most settings by running a repair upgrade. install the media creation tool from this link and choose to upgrade now: http://windows.microsoft.com/en-us/windows-10/media-creation-tool-install 4) or you can create the bootable media to do the gold standard clean install in this link, which compiles the best possible install of windows 10 that will stay that way as long as you stick with the tools and methods given: http://answers.microsoft.com/en-us/windows/wiki/windows_10-windows_install/clean-reinstall-windows-10-upgradefactory-oem/1c426bdf-79b1-4d42-be93-17378d93e587 5) there is also an automated refresh which reinstalls windows while leaving out the factory bloatware that throttles windows and causes endless issues, lets you save your files. https://www.howtogeek.com/265054/how-to-easily-reinstall-windows-10-without-the-bloatware/ feel free to ask back any questions and let me know how it goes. i'll keep working with you until it's resolved.
#
# Document 1168 :  Camera stuck showing my desktop not me!
# Document 51 :  Desktop gets stuck and never loads.
# Document 47 :  Windows 10
# Document 686 :  windows 10
# Document 64 :  Windows Store stuck on downloading

# %% [markdown]
# # Evaluation of Models

# %%
ground_truths = {}
ground_truths_f = {}
for i in range(1,50):
  ground_truths[i] = list(set(bm25_a[i]) & set(ql_a[i]) & set(tf_a[i]))
  if ground_truths[i] == []:
    ground_truths[i] = [bm25_a[i][0]]
  ground_truths_f[i] = list(set(bm25_f[i]) & set(ql_f[i]) & set(tf_f[i]))
  if len(ground_truths_f[i]) < 3:
    ground_truths_f[i] += bm25_f[i][:2] + [ql_f[i][-1]]

# %%
def calculate_precision_at_1(queries, results, relevance_judgments):
  """
  Calculates the Precision@1 score for a set of queries, results, and relevance judgments.

  Args:
    queries: A list of query strings.
    results: A list of lists, where each sublist contains the ranked IDs of documents for a corresponding query.
    relevance_judgments: A list of dictionaries, where each dictionary maps a document ID to a relevance score (e.g., 1 for relevant, 0 for non-relevant).

  Returns:
    A list of Precision@1 scores for each query.
  """

  precisions = []
  for query, documents, judgments in zip(queries, results, relevance_judgments):
    top_doc_id = documents[0]
    precision = judgments[top_doc_id] / len(documents)
    precisions.append(precision)
  return precisions

def calculate_mrr(queries, results, relevance_judgments):
  """
  Calculates the MRR score for a set of queries, results, and relevance judgments.

  Args:
    queries: A list of query strings.
    results: A list of lists, where each sublist contains the ranked IDs of documents for a corresponding query.
    relevance_judgments: A list of dictionaries, where each dictionary maps a document ID to a relevance score (e.g., 1 for relevant, 0 for non-relevant).

  Returns:
    The MRR score as a float between 0 and 1.
  """

  reciprocal_ranks = []
  for query, documents, judgments in zip(queries, results, relevance_judgments):
    for document_id in documents:
      if judgments[document_id] > 0:
        rank = documents.index(document_id) + 1
        reciprocal_rank = 1 / rank
        reciprocal_ranks.append(reciprocal_rank)
        break
  mrr = sum(reciprocal_ranks) / len(reciprocal_ranks)
  return mrr


results = [[123, 456, 789], [987, 654, 321], [10, 20, 30]]
relevance_judgments = [{123: 1}, {987: 1}, {10: 0}]

precisions = calculate_precision_at_1(queries, results, relevance_judgments)
mrr = calculate_mrr(queries, results, relevance_judgments)

print(f"Precision@1 for each query: {precisions}")
print(f"Overall MRR: {mrr}")
